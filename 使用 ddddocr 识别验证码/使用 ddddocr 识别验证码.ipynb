# %%
from ddddocr import DdddOcr
from IPython.display import Image
import cv2

# 使用 cv2 时，路径中不能含有中文

# %% [markdown]
# ## 一、图形识别
# ### 1. 案例一

# %%
Image(filename="./图片/00.png")

# %%
ocr = DdddOcr()

with open("./图片/00.png", 'rb') as f:
    image = f.read()

res = ocr.classification(image)
print(res)
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# 3umv

# %% [markdown]
# ### 2. 案例二

# %%
Image(filename="./图片/01.png")

# %%
ocr = DdddOcr()

with open("./图片/01.png", 'rb') as f:
    image = f.read()

res = ocr.classification(image)
print(res)
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# 5o3wPzdz

# %% [markdown]
# ### 3. 案例三

# %%
Image(filename="./图片/02.png")

# %%
ocr = DdddOcr()

with open("./图片/02.png", 'rb') as f:
    image = f.read()

res = ocr.classification(image)
print(res)
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# iepv

# %% [markdown]
# ### 4. 案例四

# %%
Image(filename="./图片/03.png")

# %%
ocr = DdddOcr(beta=True)

with open("./图片/03.png", 'rb') as f:
    image = f.read()

res = ocr.classification(image)
print(res)
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# ynmd

# %% [markdown]
# ### 5. 案例五

# %%
Image(filename="./图片/04.jpg")

# %%
ocr = DdddOcr(beta=True)

with open("./图片/04.jpg", 'rb') as f:
    image = f.read()

res = ocr.classification(image)
print(res)
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# 2acd

# %% [markdown]
# ### 6. 案例六

# %%
Image(filename="./图片/05.png")

# %%
ocr = DdddOcr()

with open("./图片/05.png", 'rb') as f:
    image = f.read()

res = ocr.classification(image)
print(res)
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# E233g

# %% [markdown]
# ## 二、拖动
# ### 1. 案例一

# %%
Image(filename="./拖动/1-1.png")

# %%
Image(filename="./拖动/1-2.png")

# %%
  det = DdddOcr(det=False, ocr=False)
  
  with open('./拖动/1-1.png', 'rb') as f:
      target_bytes = f.read()
  
  with open('./拖动/1-2.png', 'rb') as f:
      background_bytes = f.read()
  
  res = det.slide_match(target_bytes, background_bytes)
  
  print(res)
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# {'target_y': 45, 'target': [215, 45, 260, 91]}

# %% [markdown]
# ### 2. 案例二

# %%
Image(filename="./拖动/2-1.jpg")

# %%
Image(filename="./拖动/2-2.jpg")

# %%
  slide = DdddOcr(det=False, ocr=False)

  with open('./拖动/2-1.jpg', 'rb') as f:
      target_bytes = f.read()
  
  with open('./拖动/2-2.jpg', 'rb') as f:
      background_bytes = f.read()
  
  img = cv2.imread("bg.jpg")
  
  res = slide.slide_comparison(target_bytes, background_bytes)

  print(res)
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# {'target': [144, 76]}

# %% [markdown]
# ## 三、点选
# ### 1. 案例一

# %%
Image(filename="./click/01.jpg")

# %%
det = DdddOcr(det=True)

with open("./click/01.jpg", 'rb') as f:
    image = f.read()

poses = det.detection(image)
print(poses)

im = cv2.imread("./click/01.jpg",cv2.IMREAD_UNCHANGED)

for box in poses:
    x1, y1, x2, y2 = box
    im = cv2.rectangle(im, (x1, y1), (x2, y2), color=(0, 0, 255), thickness=2)

cv2.imwrite("./click/result_01.jpg", im)
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# [[0, 345, 30, 376], [28, 346, 59, 378], [57, 345, 88, 375], [2, 181, 67, 250], [121, 163, 188, 229], [223, 119, 291, 187]]
# True

# %% [markdown]
# ### 2. 案例二

# %%
Image(filename="./click/02.png")

# %%
det = DdddOcr(det=True)

with open("./click/02.png", 'rb') as f:
    image = f.read()

poses = det.detection(image)
print(poses)

im = cv2.imread("./click/02.png")

for box in poses:
    x1, y1, x2, y2 = box
    im = cv2.rectangle(im, (x1, y1), (x2, y2), color=(0, 0, 255), thickness=2)

cv2.imwrite("./click/result_02.jpg", im)
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# [[44, 294, 69, 319], [183, 81, 229, 123], [108, 293, 133, 320], [66, 293, 91, 319], [87, 293, 111, 319], [130, 293, 154, 319], [193, 291, 220, 320], [257, 155, 310, 205], [165, 290, 196, 322], [76, 135, 116, 177], [218, 291, 246, 321], [19, 290, 47, 320]]
# True

# %% [markdown]
# ### 3. 案例三

# %%
Image(filename="./click/03.jpg")

# %%
det = DdddOcr(det=True)

with open("./click/03.jpg", 'rb') as f:
    image = f.read()

poses = det.detection(image)
print(poses)

im = cv2.imread("./click/03.jpg")

for box in poses:
    x1, y1, x2, y2 = box
    im = cv2.rectangle(im, (x1, y1), (x2, y2), color=(0, 0, 255), thickness=2)

cv2.imwrite("./click/result_03.jpg", im)
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# [[113, 46, 154, 86], [179, 46, 213, 80], [247, 89, 286, 128], [241, 18, 281, 56]]
# True

# %% [markdown]
# ### 4. 案例四

# %%
Image(filename="./click/04.png")

# %%
det = DdddOcr(det=True)

with open("./click/04.png", 'rb') as f:
    image = f.read()

poses = det.detection(image)
print(poses)

im = cv2.imread("./click/04.png")

for box in poses:
    x1, y1, x2, y2 = box
    im = cv2.rectangle(im, (x1, y1), (x2, y2), color=(0, 0, 255), thickness=2)

cv2.imwrite("./click/result_04.png", im)
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# [[56, 64, 95, 103], [86, 20, 124, 60], [127, 50, 169, 99], [12, 26, 53, 73], [198, 93, 236, 131], [215, 7, 246, 36]]
# True

# %% [markdown]
# ### 5. 案例五

# %%
Image(filename="./click/05.jpg")

# %%
det = DdddOcr(det=True)

with open("./click/05.jpg", 'rb') as f:
    image = f.read()

poses = det.detection(image)
print(poses)

im = cv2.imread("./click/05.jpg")

for box in poses:
    x1, y1, x2, y2 = box
    im = cv2.rectangle(im, (x1, y1), (x2, y2), color=(0, 0, 255), thickness=2)

cv2.imwrite("./click/result_05.jpg", im)
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# [[249, 22, 286, 58], [86, 28, 127, 67], [143, 36, 174, 68], [110, 100, 147, 137], [54, 74, 89, 106]]
# True

# %% [markdown]
# ### 6. 封装代码

# %%
from io import BytesIO
import ddddocr
from PIL import Image, ImageDraw, ImageFont


class Ddddocr:

    def __init__(self):
        self.ocr = ddddocr.DdddOcr(show_ad=False)
        self.xy_ocr = ddddocr.DdddOcr(det=True, show_ad=False)

    def ddddocr_identify(self, captcha_bytes):
        return self.ocr.classification(captcha_bytes)

    def draw_img(self, content, xy_list):
        """画出图片"""
        # 填字字体
        font_type = "./msyhl.ttc"
        font_size = 20
        font = ImageFont.truetype(font_type, font_size)
        # 识别
        img = Image.open(BytesIO(content))
        draw = ImageDraw.Draw(img)
        words = []
        for row in xy_list:
            # 框字
            x1, y1, x2, y2 = row
            draw.line(([(x1, y1), (x1, y2), (x2, y2), (x2, y1), (x1, y1)]), width=1, fill="red")
            # 裁剪出单个字
            corp = img.crop(row)
            img_byte = BytesIO()
            corp.save(img_byte, 'png')
            # 识别出单个字
            word = self.ocr.classification(img_byte.getvalue())
            words.append(word)
            # 填字
            y = y1 - 30 if y2 > 300 else y2
            draw.text((int((x1 + x2)/2), y), word, font=font, fill="red")
        img.show()
        return words

    def ddddocr_clcik_identify(self, content, crop_size=None):
        """目标检测识别"""
        img = Image.open(BytesIO(content))
        # print(img.size)
        if crop_size:
            img = img.crop(crop_size)
            img_byte = BytesIO()
            img.save(img_byte, 'png')
            content = img_byte.getvalue()
        xy_list = self.xy_ocr.detection(content)
        words = self.draw_img(content, xy_list)
        return dict(zip(words, xy_list))

    def case_demo(self, con):
        """点选识别结果"""
        click_identify_result = self.ddddocr_clcik_identify(con, (0, 0, 344, 344))
        img = Image.open(BytesIO(con))
        img = img.crop((0, 344, 344, 384))
        img_byte = BytesIO()
        img.save(img_byte, 'png')
        # identify_words = self.ocr.classification(img_byte.getvalue())
        # print(click_identify_result)
        # words_dict = {}
        # for word in identify_words:
        #     words_dict[word] = click_identify_result.get(word)
        # print(words_dict)
        img_xy = {}
        for key, xy in click_identify_result.items():
            img_xy[key] = (int((xy[0] + xy[2]) / 2), int((xy[1] + xy[3]) / 2))
        print(img_xy)


with open('./click/01.jpg', 'rb') as f:
    con1 = f.read()

Ddddocr().case_demo(con1)
# Out:
# {'杯': (34, 215), '尾': (155, 195), '鸡': (258, 152), '': (139, 293)}

# %% [markdown]
# ### 7. 实用化

# %%
det = DdddOcr(det=True)

with open("./click/01.jpg", 'rb') as f:
    image = f.read()

poses = det.detection(image)
print(poses)

im = cv2.imread("./click/01.jpg")

for box in poses:
    x1, y1, x2, y2 = box
    im = cv2.rectangle(im, (x1, y1), (x2, y2), color=(0, 0, 255), thickness=2)

cv2.imwrite("./click/result_01.jpg", im)

chars = {}
for box in poses:
    # 对框内文字进行识别
    x1, y1, x2, y2 = box
    corp = im[y1:y2, x1:x2]
    _, tmpimg = cv2.imencode('.png', corp)
    tmp = tmpimg.tobytes()
    result = ocr.classification(tmp)
    print(result)
    chars[result] = [x1, y1, x2, y2]

print('请点击“杯”、“鸡”')

for i in ['杯', '鸡']:
    print(i, chars[i])
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# [[0, 345, 30, 376], [28, 346, 59, 378], [57, 345, 88, 375], [2, 181, 67, 250], [121, 163, 188, 229], [223, 119, 291, 187]]
# 婴
# 食
# 深
# 杯
# 尾
# 鸡
# 请点击“杯”、“鸡”
# 杯 [2, 181, 67, 250]
# 鸡 [223, 119, 291, 187]
