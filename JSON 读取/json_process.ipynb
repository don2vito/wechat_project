# %%
import json
from jsonpath import jsonpath
import requests
import pandas as pd

# %%
# 通过爬虫获取 JSON 格式文本
# 方法一：使用 json.loads() 方法 读取 JSON 格式文本
url = 'http://www.shfe.com.cn/data/dailydata/kx/kx20210219.dat'
res = requests.get(url)
json_data = json.loads(res.text)
json_data
# Out:
# {'o_curinstrument': [{'PRODUCTID': 'cu_f    ',
#    'PRODUCTGROUPID': 'cu      ',
#    'PRODUCTSORTNO': 10,
#    'PRODUCTNAME': '铜                  ',
#    'DELIVERYMONTH': '2103',
#    'PRESETTLEMENTPRICE': 62600,
#    'OPENPRICE': 63440,
#    'HIGHESTPRICE': 64330,
#    'LOWESTPRICE': 62890,
#    'CLOSEPRICE': 64170,
#    'SETTLEMENTPRICE': 63390,
#    'ZD1_CHG': 1570,
#    'ZD2_CHG': 790,
#    'VOLUME': 106671,
#    'TASVOLUME': '',
#    'OPENINTEREST': 68887,
#    'OPENINTERESTCHG': -11804,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'cu_f    ',
#    'PRODUCTGROUPID': 'cu      ',
#    'PRODUCTSORTNO': 10,
#    'PRODUCTNAME': '铜                  ',
#    'DELIVERYMONTH': '2104',
#    'PRESETTLEMENTPRICE': 62730,
#    'OPENPRICE': 63390,
#    'HIGHESTPRICE': 64470,
#    'LOWESTPRICE': 63000,
#    'CLOSEPRICE': 64320,
#    'SETTLEMENTPRICE': 63560,
#    'ZD1_CHG': 1590,
#    'ZD2_CHG': 830,
#    'VOLUME': 199534,
#    'TASVOLUME': '',
#    'OPENINTEREST': 147830,
#    'OPENINTERESTCHG': 19979,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'cu_f    ',
#    'PRODUCTGROUPID': 'cu      ',
#    'PRODUCTSORTNO': 10,
#    'PRODUCTNAME': '铜                  ',
#    'DELIVERYMONTH': '2105',
#    'PRESETTLEMENTPRICE': 62710,
#    'OPENPRICE': 63480,
#    'HIGHESTPRICE': 64510,
#    'LOWESTPRICE': 63030,
#    'CLOSEPRICE': 64370,
#    'SETTLEMENTPRICE': 63600,
#    'ZD1_CHG': 1660,
#    'ZD2_CHG': 890,
#    'VOLUME': 69650,
#    'TASVOLUME': '',
#    'OPENINTEREST': 75898,
#    'OPENINTERESTCHG': 5289,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'cu_f    ',
#    'PRODUCTGROUPID': 'cu      ',
#    'PRODUCTSORTNO': 10,
#    'PRODUCTNAME': '铜                  ',
#    'DELIVERYMONTH': '2106',
#    'PRESETTLEMENTPRICE': 62640,
#    'OPENPRICE': 63400,
#    'HIGHESTPRICE': 64470,
#    'LOWESTPRICE': 63000,
#    'CLOSEPRICE': 64390,
#    'SETTLEMENTPRICE': 63620,
#    'ZD1_CHG': 1750,
#    'ZD2_CHG': 980,
#    'VOLUME': 22045,
#    'TASVOLUME': '',
#    'OPENINTEREST': 32707,
#    'OPENINTERESTCHG': 3916,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'cu_f    ',
#    'PRODUCTGROUPID': 'cu      ',
#    'PRODUCTSORTNO': 10,
#    'PRODUCTNAME': '铜                  ',
#    'DELIVERYMONTH': '2107',
#    'PRESETTLEMENTPRICE': 62700,
#    'OPENPRICE': 63350,
#    'HIGHESTPRICE': 64420,
#    'LOWESTPRICE': 62950,
#    'CLOSEPRICE': 64330,
#    'SETTLEMENTPRICE': 63680,
#    'ZD1_CHG': 1630,
#    'ZD2_CHG': 980,
#    'VOLUME': 5058,
#    'TASVOLUME': '',
#    'OPENINTEREST': 11851,
#    'OPENINTERESTCHG': 1791,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'cu_f    ',
#    'PRODUCTGROUPID': 'cu      ',
#    'PRODUCTSORTNO': 10,
#    'PRODUCTNAME': '铜                  ',
#    'DELIVERYMONTH': '2108',
#    'PRESETTLEMENTPRICE': 62420,
#    'OPENPRICE': 63350,
#    'HIGHESTPRICE': 64390,
#    'LOWESTPRICE': 62940,
#    'CLOSEPRICE': 64220,
#    'SETTLEMENTPRICE': 63470,
#    'ZD1_CHG': 1800,
#    'ZD2_CHG': 1050,
#    'VOLUME': 323,
#    'TASVOLUME': '',
#    'OPENINTEREST': 3475,
#    'OPENINTERESTCHG': 12,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'cu_f    ',
#    'PRODUCTGROUPID': 'cu      ',
#    'PRODUCTSORTNO': 10,
#    'PRODUCTNAME': '铜                  ',
#    'DELIVERYMONTH': '2109',
#    'PRESETTLEMENTPRICE': 62470,
#    'OPENPRICE': 63350,
#    'HIGHESTPRICE': 64400,
#    'LOWESTPRICE': 62980,
#    'CLOSEPRICE': 64350,
#    'SETTLEMENTPRICE': 63520,
#    'ZD1_CHG': 1880,
#    'ZD2_CHG': 1050,
#    'VOLUME': 639,
#    'TASVOLUME': '',
#    'OPENINTEREST': 2937,
#    'OPENINTERESTCHG': 105,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'cu_f    ',
#    'PRODUCTGROUPID': 'cu      ',
#    'PRODUCTSORTNO': 10,
#    'PRODUCTNAME': '铜                  ',
#    'DELIVERYMONTH': '2110',
#    'PRESETTLEMENTPRICE': 62650,
#    'OPENPRICE': 63340,
#    'HIGHESTPRICE': 64400,
#    'LOWESTPRICE': 62980,
#    'CLOSEPRICE': 64400,
#    'SETTLEMENTPRICE': 63380,
#    'ZD1_CHG': 1750,
#    'ZD2_CHG': 730,
#    'VOLUME': 78,
#    'TASVOLUME': '',
#    'OPENINTEREST': 678,
#    'OPENINTERESTCHG': 21,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'cu_f    ',
#    'PRODUCTGROUPID': 'cu      ',
#    'PRODUCTSORTNO': 10,
#    'PRODUCTNAME': '铜                  ',
#    'DELIVERYMONTH': '2111',
#    'PRESETTLEMENTPRICE': 62630,
#    'OPENPRICE': 63370,
#    'HIGHESTPRICE': 64400,
#    'LOWESTPRICE': 63090,
#    'CLOSEPRICE': 64400,
#    'SETTLEMENTPRICE': 63660,
#    'ZD1_CHG': 1770,
#    'ZD2_CHG': 1030,
#    'VOLUME': 58,
#    'TASVOLUME': '',
#    'OPENINTEREST': 386,
#    'OPENINTERESTCHG': 22,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'cu_f    ',
#    'PRODUCTGROUPID': 'cu      ',
#    'PRODUCTSORTNO': 10,
#    'PRODUCTNAME': '铜                  ',
#    'DELIVERYMONTH': '2112',
#    'PRESETTLEMENTPRICE': 62820,
#    'OPENPRICE': 63440,
#    'HIGHESTPRICE': 64370,
#    'LOWESTPRICE': 62940,
#    'CLOSEPRICE': 64370,
#    'SETTLEMENTPRICE': 63410,
#    'ZD1_CHG': 1550,
#    'ZD2_CHG': 590,
#    'VOLUME': 79,
#    'TASVOLUME': '',
#    'OPENINTEREST': 329,
#    'OPENINTERESTCHG': 55,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'cu_f    ',
#    'PRODUCTGROUPID': 'cu      ',
#    'PRODUCTSORTNO': 10,
#    'PRODUCTNAME': '铜                  ',
#    'DELIVERYMONTH': '2201',
#    'PRESETTLEMENTPRICE': 62520,
#    'OPENPRICE': 63200,
#    'HIGHESTPRICE': 64310,
#    'LOWESTPRICE': 63090,
#    'CLOSEPRICE': 64270,
#    'SETTLEMENTPRICE': 63330,
#    'ZD1_CHG': 1750,
#    'ZD2_CHG': 810,
#    'VOLUME': 29,
#    'TASVOLUME': '',
#    'OPENINTEREST': 100,
#    'OPENINTERESTCHG': 16,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'cu_f    ',
#    'PRODUCTGROUPID': 'cu      ',
#    'PRODUCTSORTNO': 10,
#    'PRODUCTNAME': '铜                  ',
#    'DELIVERYMONTH': '2202',
#    'PRESETTLEMENTPRICE': 62480,
#    'OPENPRICE': 63100,
#    'HIGHESTPRICE': 64350,
#    'LOWESTPRICE': 63010,
#    'CLOSEPRICE': 64350,
#    'SETTLEMENTPRICE': 63650,
#    'ZD1_CHG': 1870,
#    'ZD2_CHG': 1170,
#    'VOLUME': 23,
#    'TASVOLUME': '',
#    'OPENINTEREST': 31,
#    'OPENINTERESTCHG': 14,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'cu_f    ',
#    'PRODUCTGROUPID': 'cu      ',
#    'PRODUCTSORTNO': 10,
#    'PRODUCTNAME': '铜                  ',
#    'DELIVERYMONTH': '小计',
#    'PRESETTLEMENTPRICE': '',
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': '',
#    'SETTLEMENTPRICE': '',
#    'ZD1_CHG': '',
#    'ZD2_CHG': '',
#    'VOLUME': 404187,
#    'TASVOLUME': '',
#    'OPENINTEREST': 345109,
#    'OPENINTERESTCHG': 19416,
#    'ORDERNO': 0,
#    'ORDERNO2': 50},
#   {'PRODUCTID': 'bc_f    ',
#    'PRODUCTGROUPID': 'bc      ',
#    'PRODUCTSORTNO': 15,
#    'PRODUCTNAME': '铜(BC)              ',
#    'DELIVERYMONTH': '2103',
#    'PRESETTLEMENTPRICE': 55850,
#    'OPENPRICE': 56420,
#    'HIGHESTPRICE': 57700,
#    'LOWESTPRICE': 56100,
#    'CLOSEPRICE': 57300,
#    'SETTLEMENTPRICE': 56570,
#    'ZD1_CHG': 1450,
#    'ZD2_CHG': 720,
#    'VOLUME': 390,
#    'TASVOLUME': '',
#    'OPENINTEREST': 1428,
#    'OPENINTERESTCHG': -269,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'bc_f    ',
#    'PRODUCTGROUPID': 'bc      ',
#    'PRODUCTSORTNO': 15,
#    'PRODUCTNAME': '铜(BC)              ',
#    'DELIVERYMONTH': '2104',
#    'PRESETTLEMENTPRICE': 55820,
#    'OPENPRICE': 56500,
#    'HIGHESTPRICE': 57380,
#    'LOWESTPRICE': 56100,
#    'CLOSEPRICE': 57240,
#    'SETTLEMENTPRICE': 56580,
#    'ZD1_CHG': 1420,
#    'ZD2_CHG': 760,
#    'VOLUME': 9582,
#    'TASVOLUME': '',
#    'OPENINTEREST': 12213,
#    'OPENINTERESTCHG': 184,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'bc_f    ',
#    'PRODUCTGROUPID': 'bc      ',
#    'PRODUCTSORTNO': 15,
#    'PRODUCTNAME': '铜(BC)              ',
#    'DELIVERYMONTH': '2105',
#    'PRESETTLEMENTPRICE': 55870,
#    'OPENPRICE': 56500,
#    'HIGHESTPRICE': 57370,
#    'LOWESTPRICE': 56060,
#    'CLOSEPRICE': 57340,
#    'SETTLEMENTPRICE': 56510,
#    'ZD1_CHG': 1470,
#    'ZD2_CHG': 640,
#    'VOLUME': 25206,
#    'TASVOLUME': '',
#    'OPENINTEREST': 10474,
#    'OPENINTERESTCHG': 1701,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'bc_f    ',
#    'PRODUCTGROUPID': 'bc      ',
#    'PRODUCTSORTNO': 15,
#    'PRODUCTNAME': '铜(BC)              ',
#    'DELIVERYMONTH': '2106',
#    'PRESETTLEMENTPRICE': 55980,
#    'OPENPRICE': 56520,
#    'HIGHESTPRICE': 57500,
#    'LOWESTPRICE': 56120,
#    'CLOSEPRICE': 57270,
#    'SETTLEMENTPRICE': 56520,
#    'ZD1_CHG': 1290,
#    'ZD2_CHG': 540,
#    'VOLUME': 1638,
#    'TASVOLUME': '',
#    'OPENINTEREST': 322,
#    'OPENINTERESTCHG': 16,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'bc_f    ',
#    'PRODUCTGROUPID': 'bc      ',
#    'PRODUCTSORTNO': 15,
#    'PRODUCTNAME': '铜(BC)              ',
#    'DELIVERYMONTH': '2107',
#    'PRESETTLEMENTPRICE': 56030,
#    'OPENPRICE': 56440,
#    'HIGHESTPRICE': 57360,
#    'LOWESTPRICE': 56130,
#    'CLOSEPRICE': 57320,
#    'SETTLEMENTPRICE': 56450,
#    'ZD1_CHG': 1290,
#    'ZD2_CHG': 420,
#    'VOLUME': 1542,
#    'TASVOLUME': '',
#    'OPENINTEREST': 161,
#    'OPENINTERESTCHG': 38,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'bc_f    ',
#    'PRODUCTGROUPID': 'bc      ',
#    'PRODUCTSORTNO': 15,
#    'PRODUCTNAME': '铜(BC)              ',
#    'DELIVERYMONTH': '2108',
#    'PRESETTLEMENTPRICE': 55240,
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': 56470,
#    'SETTLEMENTPRICE': 56470,
#    'ZD1_CHG': 1230,
#    'ZD2_CHG': 1230,
#    'VOLUME': 0,
#    'TASVOLUME': '',
#    'OPENINTEREST': 1,
#    'OPENINTERESTCHG': 0,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'bc_f    ',
#    'PRODUCTGROUPID': 'bc      ',
#    'PRODUCTSORTNO': 15,
#    'PRODUCTNAME': '铜(BC)              ',
#    'DELIVERYMONTH': '2109',
#    'PRESETTLEMENTPRICE': 55250,
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': 55990,
#    'SETTLEMENTPRICE': 55990,
#    'ZD1_CHG': 740,
#    'ZD2_CHG': 740,
#    'VOLUME': 0,
#    'TASVOLUME': '',
#    'OPENINTEREST': 3,
#    'OPENINTERESTCHG': 0,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'bc_f    ',
#    'PRODUCTGROUPID': 'bc      ',
#    'PRODUCTSORTNO': 15,
#    'PRODUCTNAME': '铜(BC)              ',
#    'DELIVERYMONTH': '2110',
#    'PRESETTLEMENTPRICE': 55590,
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': 56380,
#    'SETTLEMENTPRICE': 56380,
#    'ZD1_CHG': 790,
#    'ZD2_CHG': 790,
#    'VOLUME': 0,
#    'TASVOLUME': '',
#    'OPENINTEREST': 1,
#    'OPENINTERESTCHG': 0,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'bc_f    ',
#    'PRODUCTGROUPID': 'bc      ',
#    'PRODUCTSORTNO': 15,
#    'PRODUCTNAME': '铜(BC)              ',
#    'DELIVERYMONTH': '2111',
#    'PRESETTLEMENTPRICE': 55440,
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': 55940,
#    'SETTLEMENTPRICE': 55940,
#    'ZD1_CHG': 500,
#    'ZD2_CHG': 500,
#    'VOLUME': 0,
#    'TASVOLUME': '',
#    'OPENINTEREST': 1,
#    'OPENINTERESTCHG': 0,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'bc_f    ',
#    'PRODUCTGROUPID': 'bc      ',
#    'PRODUCTSORTNO': 15,
#    'PRODUCTNAME': '铜(BC)              ',
#    'DELIVERYMONTH': '2112',
#    'PRESETTLEMENTPRICE': 54800,
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': 55900,
#    'SETTLEMENTPRICE': 55900,
#    'ZD1_CHG': 1100,
#    'ZD2_CHG': 1100,
#    'VOLUME': 0,
#    'TASVOLUME': '',
#    'OPENINTEREST': 0,
#    'OPENINTERESTCHG': 0,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'bc_f    ',
#    'PRODUCTGROUPID': 'bc      ',
#    'PRODUCTSORTNO': 15,
#    'PRODUCTNAME': '铜(BC)              ',
#    'DELIVERYMONTH': '2201',
#    'PRESETTLEMENTPRICE': 54520,
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': 54520,
#    'SETTLEMENTPRICE': 54520,
#    'ZD1_CHG': 0,
#    'ZD2_CHG': 0,
#    'VOLUME': 0,
#    'TASVOLUME': '',
#    'OPENINTEREST': 0,
#    'OPENINTERESTCHG': 0,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'bc_f    ',
#    'PRODUCTGROUPID': 'bc      ',
#    'PRODUCTSORTNO': 15,
#    'PRODUCTNAME': '铜(BC)              ',
#    'DELIVERYMONTH': '2202',
#    'PRESETTLEMENTPRICE': 54280,
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': 54690,
#    'SETTLEMENTPRICE': 54690,
#    'ZD1_CHG': 410,
#    'ZD2_CHG': 410,
#    'VOLUME': 0,
#    'TASVOLUME': '',
#    'OPENINTEREST': 0,
#    'OPENINTERESTCHG': 0,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'bc_f    ',
#    'PRODUCTGROUPID': 'bc      ',
#    'PRODUCTSORTNO': 15,
#    'PRODUCTNAME': '铜(BC)              ',
#    'DELIVERYMONTH': '小计',
#    'PRESETTLEMENTPRICE': '',
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': '',
#    'SETTLEMENTPRICE': '',
#    'ZD1_CHG': '',
#    'ZD2_CHG': '',
#    'VOLUME': 38358,
#    'TASVOLUME': '',
#    'OPENINTEREST': 24604,
#    'OPENINTERESTCHG': 1670,
#    'ORDERNO': 0,
#    'ORDERNO2': 50},
#   {'PRODUCTID': 'al_f    ',
#    'PRODUCTGROUPID': 'al      ',
#    'PRODUCTSORTNO': 20,
#    'PRODUCTNAME': '铝                  ',
#    'DELIVERYMONTH': '2103',
#    'PRESETTLEMENTPRICE': 16350,
#    'OPENPRICE': 16650,
#    'HIGHESTPRICE': 16660,
#    'LOWESTPRICE': 16385,
#    'CLOSEPRICE': 16485,
#    'SETTLEMENTPRICE': 16530,
#    'ZD1_CHG': 135,
#    'ZD2_CHG': 180,
#    'VOLUME': 147864,
#    'TASVOLUME': '',
#    'OPENINTEREST': 133572,
#    'OPENINTERESTCHG': -13529,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'al_f    ',
#    'PRODUCTGROUPID': 'al      ',
#    'PRODUCTSORTNO': 20,
#    'PRODUCTNAME': '铝                  ',
#    'DELIVERYMONTH': '2104',
#    'PRESETTLEMENTPRICE': 16345,
#    'OPENPRICE': 16680,
#    'HIGHESTPRICE': 16680,
#    'LOWESTPRICE': 16385,
#    'CLOSEPRICE': 16490,
#    'SETTLEMENTPRICE': 16525,
#    'ZD1_CHG': 145,
#    'ZD2_CHG': 180,
#    'VOLUME': 152538,
#    'TASVOLUME': '',
#    'OPENINTEREST': 190833,
#    'OPENINTERESTCHG': 17823,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'al_f    ',
#    'PRODUCTGROUPID': 'al      ',
#    'PRODUCTSORTNO': 20,
#    'PRODUCTNAME': '铝                  ',
#    'DELIVERYMONTH': '2105',
#    'PRESETTLEMENTPRICE': 16270,
#    'OPENPRICE': 16460,
#    'HIGHESTPRICE': 16570,
#    'LOWESTPRICE': 16335,
#    'CLOSEPRICE': 16425,
#    'SETTLEMENTPRICE': 16470,
#    'ZD1_CHG': 155,
#    'ZD2_CHG': 200,
#    'VOLUME': 56968,
#    'TASVOLUME': '',
#    'OPENINTEREST': 91237,
#    'OPENINTERESTCHG': 6566,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'al_f    ',
#    'PRODUCTGROUPID': 'al      ',
#    'PRODUCTSORTNO': 20,
#    'PRODUCTNAME': '铝                  ',
#    'DELIVERYMONTH': '2106',
#    'PRESETTLEMENTPRICE': 16200,
#    'OPENPRICE': 16350,
#    'HIGHESTPRICE': 16465,
#    'LOWESTPRICE': 16250,
#    'CLOSEPRICE': 16335,
#    'SETTLEMENTPRICE': 16365,
#    'ZD1_CHG': 135,
#    'ZD2_CHG': 165,
#    'VOLUME': 16039,
#    'TASVOLUME': '',
#    'OPENINTEREST': 31252,
#    'OPENINTERESTCHG': 441,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'al_f    ',
#    'PRODUCTGROUPID': 'al      ',
#    'PRODUCTSORTNO': 20,
#    'PRODUCTNAME': '铝                  ',
#    'DELIVERYMONTH': '2107',
#    'PRESETTLEMENTPRICE': 16065,
#    'OPENPRICE': 16250,
#    'HIGHESTPRICE': 16370,
#    'LOWESTPRICE': 16155,
#    'CLOSEPRICE': 16255,
#    'SETTLEMENTPRICE': 16270,
#    'ZD1_CHG': 190,
#    'ZD2_CHG': 205,
#    'VOLUME': 3574,
#    'TASVOLUME': '',
#    'OPENINTEREST': 12016,
#    'OPENINTERESTCHG': 1425,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'al_f    ',
#    'PRODUCTGROUPID': 'al      ',
#    'PRODUCTSORTNO': 20,
#    'PRODUCTNAME': '铝                  ',
#    'DELIVERYMONTH': '2108',
#    'PRESETTLEMENTPRICE': 15965,
#    'OPENPRICE': 16225,
#    'HIGHESTPRICE': 16330,
#    'LOWESTPRICE': 16125,
#    'CLOSEPRICE': 16240,
#    'SETTLEMENTPRICE': 16200,
#    'ZD1_CHG': 275,
#    'ZD2_CHG': 235,
#    'VOLUME': 377,
#    'TASVOLUME': '',
#    'OPENINTEREST': 3042,
#    'OPENINTERESTCHG': 44,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'al_f    ',
#    'PRODUCTGROUPID': 'al      ',
#    'PRODUCTSORTNO': 20,
#    'PRODUCTNAME': '铝                  ',
#    'DELIVERYMONTH': '2109',
#    'PRESETTLEMENTPRICE': 16045,
#    'OPENPRICE': 16195,
#    'HIGHESTPRICE': 16285,
#    'LOWESTPRICE': 16040,
#    'CLOSEPRICE': 16150,
#    'SETTLEMENTPRICE': 16135,
#    'ZD1_CHG': 105,
#    'ZD2_CHG': 90,
#    'VOLUME': 318,
#    'TASVOLUME': '',
#    'OPENINTEREST': 2377,
#    'OPENINTERESTCHG': 8,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'al_f    ',
#    'PRODUCTGROUPID': 'al      ',
#    'PRODUCTSORTNO': 20,
#    'PRODUCTNAME': '铝                  ',
#    'DELIVERYMONTH': '2110',
#    'PRESETTLEMENTPRICE': 16035,
#    'OPENPRICE': 16205,
#    'HIGHESTPRICE': 16265,
#    'LOWESTPRICE': 16050,
#    'CLOSEPRICE': 16085,
#    'SETTLEMENTPRICE': 16140,
#    'ZD1_CHG': 50,
#    'ZD2_CHG': 105,
#    'VOLUME': 43,
#    'TASVOLUME': '',
#    'OPENINTEREST': 701,
#    'OPENINTERESTCHG': 3,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'al_f    ',
#    'PRODUCTGROUPID': 'al      ',
#    'PRODUCTSORTNO': 20,
#    'PRODUCTNAME': '铝                  ',
#    'DELIVERYMONTH': '2111',
#    'PRESETTLEMENTPRICE': 15925,
#    'OPENPRICE': 16030,
#    'HIGHESTPRICE': 16105,
#    'LOWESTPRICE': 16020,
#    'CLOSEPRICE': 16105,
#    'SETTLEMENTPRICE': 16035,
#    'ZD1_CHG': 180,
#    'ZD2_CHG': 110,
#    'VOLUME': 10,
#    'TASVOLUME': '',
#    'OPENINTEREST': 521,
#    'OPENINTERESTCHG': -7,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'al_f    ',
#    'PRODUCTGROUPID': 'al      ',
#    'PRODUCTSORTNO': 20,
#    'PRODUCTNAME': '铝                  ',
#    'DELIVERYMONTH': '2112',
#    'PRESETTLEMENTPRICE': 15870,
#    'OPENPRICE': 16130,
#    'HIGHESTPRICE': 16130,
#    'LOWESTPRICE': 16020,
#    'CLOSEPRICE': 16100,
#    'SETTLEMENTPRICE': 16100,
#    'ZD1_CHG': 230,
#    'ZD2_CHG': 230,
#    'VOLUME': 28,
#    'TASVOLUME': '',
#    'OPENINTEREST': 990,
#    'OPENINTERESTCHG': 0,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'al_f    ',
#    'PRODUCTGROUPID': 'al      ',
#    'PRODUCTSORTNO': 20,
#    'PRODUCTNAME': '铝                  ',
#    'DELIVERYMONTH': '2201',
#    'PRESETTLEMENTPRICE': 15945,
#    'OPENPRICE': 16140,
#    'HIGHESTPRICE': 16140,
#    'LOWESTPRICE': 16005,
#    'CLOSEPRICE': 16025,
#    'SETTLEMENTPRICE': 16060,
#    'ZD1_CHG': 80,
#    'ZD2_CHG': 115,
#    'VOLUME': 15,
#    'TASVOLUME': '',
#    'OPENINTEREST': 107,
#    'OPENINTERESTCHG': 9,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'al_f    ',
#    'PRODUCTGROUPID': 'al      ',
#    'PRODUCTSORTNO': 20,
#    'PRODUCTNAME': '铝                  ',
#    'DELIVERYMONTH': '2202',
#    'PRESETTLEMENTPRICE': 15995,
#    'OPENPRICE': 16065,
#    'HIGHESTPRICE': 16065,
#    'LOWESTPRICE': 15985,
#    'CLOSEPRICE': 15985,
#    'SETTLEMENTPRICE': 15995,
#    'ZD1_CHG': -10,
#    'ZD2_CHG': 0,
#    'VOLUME': 6,
#    'TASVOLUME': '',
#    'OPENINTEREST': 9,
#    'OPENINTERESTCHG': 6,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'al_f    ',
#    'PRODUCTGROUPID': 'al      ',
#    'PRODUCTSORTNO': 20,
#    'PRODUCTNAME': '铝                  ',
#    'DELIVERYMONTH': '小计',
#    'PRESETTLEMENTPRICE': '',
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': '',
#    'SETTLEMENTPRICE': '',
#    'ZD1_CHG': '',
#    'ZD2_CHG': '',
#    'VOLUME': 377780,
#    'TASVOLUME': '',
#    'OPENINTEREST': 466657,
#    'OPENINTERESTCHG': 12789,
#    'ORDERNO': 0,
#    'ORDERNO2': 50},
#   {'PRODUCTID': 'zn_f    ',
#    'PRODUCTGROUPID': 'zn      ',
#    'PRODUCTSORTNO': 30,
#    'PRODUCTNAME': '锌                  ',
#    'DELIVERYMONTH': '2103',
#    'PRESETTLEMENTPRICE': 21160,
#    'OPENPRICE': 21415,
#    'HIGHESTPRICE': 21670,
#    'LOWESTPRICE': 21335,
#    'CLOSEPRICE': 21630,
#    'SETTLEMENTPRICE': 21510,
#    'ZD1_CHG': 470,
#    'ZD2_CHG': 350,
#    'VOLUME': 108715,
#    'TASVOLUME': '',
#    'OPENINTEREST': 60847,
#    'OPENINTERESTCHG': -2884,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'zn_f    ',
#    'PRODUCTGROUPID': 'zn      ',
#    'PRODUCTSORTNO': 30,
#    'PRODUCTNAME': '锌                  ',
#    'DELIVERYMONTH': '2104',
#    'PRESETTLEMENTPRICE': 21100,
#    'OPENPRICE': 21435,
#    'HIGHESTPRICE': 21640,
#    'LOWESTPRICE': 21310,
#    'CLOSEPRICE': 21600,
#    'SETTLEMENTPRICE': 21475,
#    'ZD1_CHG': 500,
#    'ZD2_CHG': 375,
#    'VOLUME': 74742,
#    'TASVOLUME': '',
#    'OPENINTEREST': 60422,
#    'OPENINTERESTCHG': 5640,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'zn_f    ',
#    'PRODUCTGROUPID': 'zn      ',
#    'PRODUCTSORTNO': 30,
#    'PRODUCTNAME': '锌                  ',
#    'DELIVERYMONTH': '2105',
#    'PRESETTLEMENTPRICE': 21055,
#    'OPENPRICE': 21300,
#    'HIGHESTPRICE': 21595,
#    'LOWESTPRICE': 21265,
#    'CLOSEPRICE': 21565,
#    'SETTLEMENTPRICE': 21425,
#    'ZD1_CHG': 510,
#    'ZD2_CHG': 370,
#    'VOLUME': 31233,
#    'TASVOLUME': '',
#    'OPENINTEREST': 28463,
#    'OPENINTERESTCHG': 2541,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'zn_f    ',
#    'PRODUCTGROUPID': 'zn      ',
#    'PRODUCTSORTNO': 30,
#    'PRODUCTNAME': '锌                  ',
#    'DELIVERYMONTH': '2106',
#    'PRESETTLEMENTPRICE': 21015,
#    'OPENPRICE': 21290,
#    'HIGHESTPRICE': 21560,
#    'LOWESTPRICE': 21210,
#    'CLOSEPRICE': 21535,
#    'SETTLEMENTPRICE': 21380,
#    'ZD1_CHG': 520,
#    'ZD2_CHG': 365,
#    'VOLUME': 5277,
#    'TASVOLUME': '',
#    'OPENINTEREST': 7297,
#    'OPENINTERESTCHG': 1163,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'zn_f    ',
#    'PRODUCTGROUPID': 'zn      ',
#    'PRODUCTSORTNO': 30,
#    'PRODUCTNAME': '锌                  ',
#    'DELIVERYMONTH': '2107',
#    'PRESETTLEMENTPRICE': 20955,
#    'OPENPRICE': 21190,
#    'HIGHESTPRICE': 21475,
#    'LOWESTPRICE': 21160,
#    'CLOSEPRICE': 21475,
#    'SETTLEMENTPRICE': 21325,
#    'ZD1_CHG': 520,
#    'ZD2_CHG': 370,
#    'VOLUME': 201,
#    'TASVOLUME': '',
#    'OPENINTEREST': 835,
#    'OPENINTERESTCHG': 44,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'zn_f    ',
#    'PRODUCTGROUPID': 'zn      ',
#    'PRODUCTSORTNO': 30,
#    'PRODUCTNAME': '锌                  ',
#    'DELIVERYMONTH': '2108',
#    'PRESETTLEMENTPRICE': 20880,
#    'OPENPRICE': 21270,
#    'HIGHESTPRICE': 21390,
#    'LOWESTPRICE': 21150,
#    'CLOSEPRICE': 21390,
#    'SETTLEMENTPRICE': 21245,
#    'ZD1_CHG': 510,
#    'ZD2_CHG': 365,
#    'VOLUME': 5,
#    'TASVOLUME': '',
#    'OPENINTEREST': 189,
#    'OPENINTERESTCHG': -3,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'zn_f    ',
#    'PRODUCTGROUPID': 'zn      ',
#    'PRODUCTSORTNO': 30,
#    'PRODUCTNAME': '锌                  ',
#    'DELIVERYMONTH': '2109',
#    'PRESETTLEMENTPRICE': 20905,
#    'OPENPRICE': 21200,
#    'HIGHESTPRICE': 21435,
#    'LOWESTPRICE': 21115,
#    'CLOSEPRICE': 21435,
#    'SETTLEMENTPRICE': 21260,
#    'ZD1_CHG': 530,
#    'ZD2_CHG': 355,
#    'VOLUME': 33,
#    'TASVOLUME': '',
#    'OPENINTEREST': 251,
#    'OPENINTERESTCHG': 19,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'zn_f    ',
#    'PRODUCTGROUPID': 'zn      ',
#    'PRODUCTSORTNO': 30,
#    'PRODUCTNAME': '锌                  ',
#    'DELIVERYMONTH': '2110',
#    'PRESETTLEMENTPRICE': 20795,
#    'OPENPRICE': 21100,
#    'HIGHESTPRICE': 21120,
#    'LOWESTPRICE': 21100,
#    'CLOSEPRICE': 21120,
#    'SETTLEMENTPRICE': 21110,
#    'ZD1_CHG': 325,
#    'ZD2_CHG': 315,
#    'VOLUME': 2,
#    'TASVOLUME': '',
#    'OPENINTEREST': 110,
#    'OPENINTERESTCHG': 0,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'zn_f    ',
#    'PRODUCTGROUPID': 'zn      ',
#    'PRODUCTSORTNO': 30,
#    'PRODUCTNAME': '锌                  ',
#    'DELIVERYMONTH': '2111',
#    'PRESETTLEMENTPRICE': 20930,
#    'OPENPRICE': 21220,
#    'HIGHESTPRICE': 21240,
#    'LOWESTPRICE': 21100,
#    'CLOSEPRICE': 21100,
#    'SETTLEMENTPRICE': 21160,
#    'ZD1_CHG': 170,
#    'ZD2_CHG': 230,
#    'VOLUME': 11,
#    'TASVOLUME': '',
#    'OPENINTEREST': 67,
#    'OPENINTERESTCHG': -2,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'zn_f    ',
#    'PRODUCTGROUPID': 'zn      ',
#    'PRODUCTSORTNO': 30,
#    'PRODUCTNAME': '锌                  ',
#    'DELIVERYMONTH': '2112',
#    'PRESETTLEMENTPRICE': 20765,
#    'OPENPRICE': 21050,
#    'HIGHESTPRICE': 21200,
#    'LOWESTPRICE': 21050,
#    'CLOSEPRICE': 21080,
#    'SETTLEMENTPRICE': 21145,
#    'ZD1_CHG': 315,
#    'ZD2_CHG': 380,
#    'VOLUME': 10,
#    'TASVOLUME': '',
#    'OPENINTEREST': 113,
#    'OPENINTERESTCHG': -6,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'zn_f    ',
#    'PRODUCTGROUPID': 'zn      ',
#    'PRODUCTSORTNO': 30,
#    'PRODUCTNAME': '锌                  ',
#    'DELIVERYMONTH': '2201',
#    'PRESETTLEMENTPRICE': 20760,
#    'OPENPRICE': 21035,
#    'HIGHESTPRICE': 21095,
#    'LOWESTPRICE': 21035,
#    'CLOSEPRICE': 21085,
#    'SETTLEMENTPRICE': 21070,
#    'ZD1_CHG': 325,
#    'ZD2_CHG': 310,
#    'VOLUME': 5,
#    'TASVOLUME': '',
#    'OPENINTEREST': 22,
#    'OPENINTERESTCHG': -1,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'zn_f    ',
#    'PRODUCTGROUPID': 'zn      ',
#    'PRODUCTSORTNO': 30,
#    'PRODUCTNAME': '锌                  ',
#    'DELIVERYMONTH': '2202',
#    'PRESETTLEMENTPRICE': 20800,
#    'OPENPRICE': 20895,
#    'HIGHESTPRICE': 21355,
#    'LOWESTPRICE': 20895,
#    'CLOSEPRICE': 21150,
#    'SETTLEMENTPRICE': 21090,
#    'ZD1_CHG': 350,
#    'ZD2_CHG': 290,
#    'VOLUME': 5,
#    'TASVOLUME': '',
#    'OPENINTEREST': 3,
#    'OPENINTERESTCHG': 1,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'zn_f    ',
#    'PRODUCTGROUPID': 'zn      ',
#    'PRODUCTSORTNO': 30,
#    'PRODUCTNAME': '锌                  ',
#    'DELIVERYMONTH': '小计',
#    'PRESETTLEMENTPRICE': '',
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': '',
#    'SETTLEMENTPRICE': '',
#    'ZD1_CHG': '',
#    'ZD2_CHG': '',
#    'VOLUME': 220239,
#    'TASVOLUME': '',
#    'OPENINTEREST': 158619,
#    'OPENINTERESTCHG': 6512,
#    'ORDERNO': 0,
#    'ORDERNO2': 50},
#   {'PRODUCTID': 'pb_f    ',
#    'PRODUCTGROUPID': 'pb      ',
#    'PRODUCTSORTNO': 40,
#    'PRODUCTNAME': '铅                  ',
#    'DELIVERYMONTH': '2103',
#    'PRESETTLEMENTPRICE': 15485,
#    'OPENPRICE': 15640,
#    'HIGHESTPRICE': 15670,
#    'LOWESTPRICE': 15245,
#    'CLOSEPRICE': 15570,
#    'SETTLEMENTPRICE': 15485,
#    'ZD1_CHG': 85,
#    'ZD2_CHG': 0,
#    'VOLUME': 59999,
#    'TASVOLUME': '',
#    'OPENINTEREST': 26582,
#    'OPENINTERESTCHG': -1106,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'pb_f    ',
#    'PRODUCTGROUPID': 'pb      ',
#    'PRODUCTSORTNO': 40,
#    'PRODUCTNAME': '铅                  ',
#    'DELIVERYMONTH': '2104',
#    'PRESETTLEMENTPRICE': 15505,
#    'OPENPRICE': 15625,
#    'HIGHESTPRICE': 15685,
#    'LOWESTPRICE': 15300,
#    'CLOSEPRICE': 15600,
#    'SETTLEMENTPRICE': 15510,
#    'ZD1_CHG': 95,
#    'ZD2_CHG': 5,
#    'VOLUME': 39940,
#    'TASVOLUME': '',
#    'OPENINTEREST': 21237,
#    'OPENINTERESTCHG': 4698,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'pb_f    ',
#    'PRODUCTGROUPID': 'pb      ',
#    'PRODUCTSORTNO': 40,
#    'PRODUCTNAME': '铅                  ',
#    'DELIVERYMONTH': '2105',
#    'PRESETTLEMENTPRICE': 15510,
#    'OPENPRICE': 15670,
#    'HIGHESTPRICE': 15690,
#    'LOWESTPRICE': 15305,
#    'CLOSEPRICE': 15570,
#    'SETTLEMENTPRICE': 15510,
#    'ZD1_CHG': 60,
#    'ZD2_CHG': 0,
#    'VOLUME': 18898,
#    'TASVOLUME': '',
#    'OPENINTEREST': 14926,
#    'OPENINTERESTCHG': 3690,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'pb_f    ',
#    'PRODUCTGROUPID': 'pb      ',
#    'PRODUCTSORTNO': 40,
#    'PRODUCTNAME': '铅                  ',
#    'DELIVERYMONTH': '2106',
#    'PRESETTLEMENTPRICE': 15540,
#    'OPENPRICE': 15605,
#    'HIGHESTPRICE': 15665,
#    'LOWESTPRICE': 15295,
#    'CLOSEPRICE': 15580,
#    'SETTLEMENTPRICE': 15545,
#    'ZD1_CHG': 40,
#    'ZD2_CHG': 5,
#    'VOLUME': 2213,
#    'TASVOLUME': '',
#    'OPENINTEREST': 5126,
#    'OPENINTERESTCHG': 1249,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'pb_f    ',
#    'PRODUCTGROUPID': 'pb      ',
#    'PRODUCTSORTNO': 40,
#    'PRODUCTNAME': '铅                  ',
#    'DELIVERYMONTH': '2107',
#    'PRESETTLEMENTPRICE': 15535,
#    'OPENPRICE': 15605,
#    'HIGHESTPRICE': 15705,
#    'LOWESTPRICE': 15315,
#    'CLOSEPRICE': 15555,
#    'SETTLEMENTPRICE': 15585,
#    'ZD1_CHG': 20,
#    'ZD2_CHG': 50,
#    'VOLUME': 98,
#    'TASVOLUME': '',
#    'OPENINTEREST': 881,
#    'OPENINTERESTCHG': 17,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'pb_f    ',
#    'PRODUCTGROUPID': 'pb      ',
#    'PRODUCTSORTNO': 40,
#    'PRODUCTNAME': '铅                  ',
#    'DELIVERYMONTH': '2108',
#    'PRESETTLEMENTPRICE': 15605,
#    'OPENPRICE': 15650,
#    'HIGHESTPRICE': 15760,
#    'LOWESTPRICE': 15380,
#    'CLOSEPRICE': 15540,
#    'SETTLEMENTPRICE': 15590,
#    'ZD1_CHG': -65,
#    'ZD2_CHG': -15,
#    'VOLUME': 18,
#    'TASVOLUME': '',
#    'OPENINTEREST': 271,
#    'OPENINTERESTCHG': 7,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'pb_f    ',
#    'PRODUCTGROUPID': 'pb      ',
#    'PRODUCTSORTNO': 40,
#    'PRODUCTNAME': '铅                  ',
#    'DELIVERYMONTH': '2109',
#    'PRESETTLEMENTPRICE': 15580,
#    'OPENPRICE': 15635,
#    'HIGHESTPRICE': 15780,
#    'LOWESTPRICE': 15360,
#    'CLOSEPRICE': 15580,
#    'SETTLEMENTPRICE': 15580,
#    'ZD1_CHG': 0,
#    'ZD2_CHG': 0,
#    'VOLUME': 83,
#    'TASVOLUME': '',
#    'OPENINTEREST': 157,
#    'OPENINTERESTCHG': 9,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'pb_f    ',
#    'PRODUCTGROUPID': 'pb      ',
#    'PRODUCTSORTNO': 40,
#    'PRODUCTNAME': '铅                  ',
#    'DELIVERYMONTH': '2110',
#    'PRESETTLEMENTPRICE': 15600,
#    'OPENPRICE': 15715,
#    'HIGHESTPRICE': 15715,
#    'LOWESTPRICE': 15550,
#    'CLOSEPRICE': 15575,
#    'SETTLEMENTPRICE': 15610,
#    'ZD1_CHG': -25,
#    'ZD2_CHG': 10,
#    'VOLUME': 6,
#    'TASVOLUME': '',
#    'OPENINTEREST': 54,
#    'OPENINTERESTCHG': 0,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'pb_f    ',
#    'PRODUCTGROUPID': 'pb      ',
#    'PRODUCTSORTNO': 40,
#    'PRODUCTNAME': '铅                  ',
#    'DELIVERYMONTH': '2111',
#    'PRESETTLEMENTPRICE': 15555,
#    'OPENPRICE': 15565,
#    'HIGHESTPRICE': 15585,
#    'LOWESTPRICE': 15430,
#    'CLOSEPRICE': 15585,
#    'SETTLEMENTPRICE': 15480,
#    'ZD1_CHG': 30,
#    'ZD2_CHG': -75,
#    'VOLUME': 9,
#    'TASVOLUME': '',
#    'OPENINTEREST': 50,
#    'OPENINTERESTCHG': -2,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'pb_f    ',
#    'PRODUCTGROUPID': 'pb      ',
#    'PRODUCTSORTNO': 40,
#    'PRODUCTNAME': '铅                  ',
#    'DELIVERYMONTH': '2112',
#    'PRESETTLEMENTPRICE': 15540,
#    'OPENPRICE': 15760,
#    'HIGHESTPRICE': 15760,
#    'LOWESTPRICE': 15580,
#    'CLOSEPRICE': 15580,
#    'SETTLEMENTPRICE': 15670,
#    'ZD1_CHG': 40,
#    'ZD2_CHG': 130,
#    'VOLUME': 2,
#    'TASVOLUME': '',
#    'OPENINTEREST': 26,
#    'OPENINTERESTCHG': 1,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'pb_f    ',
#    'PRODUCTGROUPID': 'pb      ',
#    'PRODUCTSORTNO': 40,
#    'PRODUCTNAME': '铅                  ',
#    'DELIVERYMONTH': '2201',
#    'PRESETTLEMENTPRICE': 15640,
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': 15640,
#    'SETTLEMENTPRICE': 15640,
#    'ZD1_CHG': 0,
#    'ZD2_CHG': 0,
#    'VOLUME': 0,
#    'TASVOLUME': '',
#    'OPENINTEREST': 8,
#    'OPENINTERESTCHG': 0,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'pb_f    ',
#    'PRODUCTGROUPID': 'pb      ',
#    'PRODUCTSORTNO': 40,
#    'PRODUCTNAME': '铅                  ',
#    'DELIVERYMONTH': '2202',
#    'PRESETTLEMENTPRICE': 15400,
#    'OPENPRICE': 15770,
#    'HIGHESTPRICE': 15770,
#    'LOWESTPRICE': 15500,
#    'CLOSEPRICE': 15570,
#    'SETTLEMENTPRICE': 15610,
#    'ZD1_CHG': 170,
#    'ZD2_CHG': 210,
#    'VOLUME': 4,
#    'TASVOLUME': '',
#    'OPENINTEREST': 10,
#    'OPENINTERESTCHG': 4,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'pb_f    ',
#    'PRODUCTGROUPID': 'pb      ',
#    'PRODUCTSORTNO': 40,
#    'PRODUCTNAME': '铅                  ',
#    'DELIVERYMONTH': '小计',
#    'PRESETTLEMENTPRICE': '',
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': '',
#    'SETTLEMENTPRICE': '',
#    'ZD1_CHG': '',
#    'ZD2_CHG': '',
#    'VOLUME': 121270,
#    'TASVOLUME': '',
#    'OPENINTEREST': 69328,
#    'OPENINTERESTCHG': 8567,
#    'ORDERNO': 0,
#    'ORDERNO2': 50},
#   {'PRODUCTID': 'ni_f    ',
#    'PRODUCTGROUPID': 'ni      ',
#    'PRODUCTSORTNO': 45,
#    'PRODUCTNAME': '镍                  ',
#    'DELIVERYMONTH': '2103',
#    'PRESETTLEMENTPRICE': 138380,
#    'OPENPRICE': 139370,
#    'HIGHESTPRICE': 144620,
#    'LOWESTPRICE': 139370,
#    'CLOSEPRICE': 143760,
#    'SETTLEMENTPRICE': 141660,
#    'ZD1_CHG': 5380,
#    'ZD2_CHG': 3280,
#    'VOLUME': 25943,
#    'TASVOLUME': '',
#    'OPENINTEREST': 16119,
#    'OPENINTERESTCHG': -2599,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'ni_f    ',
#    'PRODUCTGROUPID': 'ni      ',
#    'PRODUCTSORTNO': 45,
#    'PRODUCTNAME': '镍                  ',
#    'DELIVERYMONTH': '2104',
#    'PRESETTLEMENTPRICE': 138560,
#    'OPENPRICE': 139890,
#    'HIGHESTPRICE': 144990,
#    'LOWESTPRICE': 139740,
#    'CLOSEPRICE': 144050,
#    'SETTLEMENTPRICE': 142040,
#    'ZD1_CHG': 5490,
#    'ZD2_CHG': 3480,
#    'VOLUME': 567694,
#    'TASVOLUME': '',
#    'OPENINTEREST': 209459,
#    'OPENINTERESTCHG': 36902,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'ni_f    ',
#    'PRODUCTGROUPID': 'ni      ',
#    'PRODUCTSORTNO': 45,
#    'PRODUCTNAME': '镍                  ',
#    'DELIVERYMONTH': '2105',
#    'PRESETTLEMENTPRICE': 138480,
#    'OPENPRICE': 139200,
#    'HIGHESTPRICE': 144700,
#    'LOWESTPRICE': 139200,
#    'CLOSEPRICE': 143880,
#    'SETTLEMENTPRICE': 141910,
#    'ZD1_CHG': 5400,
#    'ZD2_CHG': 3430,
#    'VOLUME': 75239,
#    'TASVOLUME': '',
#    'OPENINTEREST': 64521,
#    'OPENINTERESTCHG': 11722,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'ni_f    ',
#    'PRODUCTGROUPID': 'ni      ',
#    'PRODUCTSORTNO': 45,
#    'PRODUCTNAME': '镍                  ',
#    'DELIVERYMONTH': '2106',
#    'PRESETTLEMENTPRICE': 138410,
#    'OPENPRICE': 139000,
#    'HIGHESTPRICE': 144520,
#    'LOWESTPRICE': 139000,
#    'CLOSEPRICE': 143820,
#    'SETTLEMENTPRICE': 141930,
#    'ZD1_CHG': 5410,
#    'ZD2_CHG': 3520,
#    'VOLUME': 46062,
#    'TASVOLUME': '',
#    'OPENINTEREST': 10394,
#    'OPENINTERESTCHG': 2324,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'ni_f    ',
#    'PRODUCTGROUPID': 'ni      ',
#    'PRODUCTSORTNO': 45,
#    'PRODUCTNAME': '镍                  ',
#    'DELIVERYMONTH': '2107',
#    'PRESETTLEMENTPRICE': 138310,
#    'OPENPRICE': 139370,
#    'HIGHESTPRICE': 144260,
#    'LOWESTPRICE': 139370,
#    'CLOSEPRICE': 144100,
#    'SETTLEMENTPRICE': 142630,
#    'ZD1_CHG': 5790,
#    'ZD2_CHG': 4320,
#    'VOLUME': 155,
#    'TASVOLUME': '',
#    'OPENINTEREST': 309,
#    'OPENINTERESTCHG': 34,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'ni_f    ',
#    'PRODUCTGROUPID': 'ni      ',
#    'PRODUCTSORTNO': 45,
#    'PRODUCTNAME': '镍                  ',
#    'DELIVERYMONTH': '2108',
#    'PRESETTLEMENTPRICE': 138480,
#    'OPENPRICE': 141900,
#    'HIGHESTPRICE': 142460,
#    'LOWESTPRICE': 140980,
#    'CLOSEPRICE': 142460,
#    'SETTLEMENTPRICE': 141890,
#    'ZD1_CHG': 3980,
#    'ZD2_CHG': 3410,
#    'VOLUME': 11,
#    'TASVOLUME': '',
#    'OPENINTEREST': 83,
#    'OPENINTERESTCHG': 6,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'ni_f    ',
#    'PRODUCTGROUPID': 'ni      ',
#    'PRODUCTSORTNO': 45,
#    'PRODUCTNAME': '镍                  ',
#    'DELIVERYMONTH': '2109',
#    'PRESETTLEMENTPRICE': 138920,
#    'OPENPRICE': 140390,
#    'HIGHESTPRICE': 144680,
#    'LOWESTPRICE': 140150,
#    'CLOSEPRICE': 144680,
#    'SETTLEMENTPRICE': 142300,
#    'ZD1_CHG': 5760,
#    'ZD2_CHG': 3380,
#    'VOLUME': 1457,
#    'TASVOLUME': '',
#    'OPENINTEREST': 2406,
#    'OPENINTERESTCHG': 289,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'ni_f    ',
#    'PRODUCTGROUPID': 'ni      ',
#    'PRODUCTSORTNO': 45,
#    'PRODUCTNAME': '镍                  ',
#    'DELIVERYMONTH': '2110',
#    'PRESETTLEMENTPRICE': 138820,
#    'OPENPRICE': 140140,
#    'HIGHESTPRICE': 144550,
#    'LOWESTPRICE': 140140,
#    'CLOSEPRICE': 144120,
#    'SETTLEMENTPRICE': 141970,
#    'ZD1_CHG': 5300,
#    'ZD2_CHG': 3150,
#    'VOLUME': 55,
#    'TASVOLUME': '',
#    'OPENINTEREST': 169,
#    'OPENINTERESTCHG': 12,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'ni_f    ',
#    'PRODUCTGROUPID': 'ni      ',
#    'PRODUCTSORTNO': 45,
#    'PRODUCTNAME': '镍                  ',
#    'DELIVERYMONTH': '2111',
#    'PRESETTLEMENTPRICE': 138970,
#    'OPENPRICE': 140700,
#    'HIGHESTPRICE': 144630,
#    'LOWESTPRICE': 140700,
#    'CLOSEPRICE': 144360,
#    'SETTLEMENTPRICE': 142970,
#    'ZD1_CHG': 5390,
#    'ZD2_CHG': 4000,
#    'VOLUME': 11,
#    'TASVOLUME': '',
#    'OPENINTEREST': 88,
#    'OPENINTERESTCHG': 4,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'ni_f    ',
#    'PRODUCTGROUPID': 'ni      ',
#    'PRODUCTSORTNO': 45,
#    'PRODUCTNAME': '镍                  ',
#    'DELIVERYMONTH': '2112',
#    'PRESETTLEMENTPRICE': 139010,
#    'OPENPRICE': 140810,
#    'HIGHESTPRICE': 142880,
#    'LOWESTPRICE': 140810,
#    'CLOSEPRICE': 142880,
#    'SETTLEMENTPRICE': 141690,
#    'ZD1_CHG': 3870,
#    'ZD2_CHG': 2680,
#    'VOLUME': 85,
#    'TASVOLUME': '',
#    'OPENINTEREST': 105,
#    'OPENINTERESTCHG': -31,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'ni_f    ',
#    'PRODUCTGROUPID': 'ni      ',
#    'PRODUCTSORTNO': 45,
#    'PRODUCTNAME': '镍                  ',
#    'DELIVERYMONTH': '2201',
#    'PRESETTLEMENTPRICE': 139290,
#    'OPENPRICE': 141100,
#    'HIGHESTPRICE': 144110,
#    'LOWESTPRICE': 141100,
#    'CLOSEPRICE': 144050,
#    'SETTLEMENTPRICE': 142450,
#    'ZD1_CHG': 4760,
#    'ZD2_CHG': 3160,
#    'VOLUME': 30,
#    'TASVOLUME': '',
#    'OPENINTEREST': 85,
#    'OPENINTERESTCHG': 9,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'ni_f    ',
#    'PRODUCTGROUPID': 'ni      ',
#    'PRODUCTSORTNO': 45,
#    'PRODUCTNAME': '镍                  ',
#    'DELIVERYMONTH': '2202',
#    'PRESETTLEMENTPRICE': 138800,
#    'OPENPRICE': 139990,
#    'HIGHESTPRICE': 144480,
#    'LOWESTPRICE': 139990,
#    'CLOSEPRICE': 144480,
#    'SETTLEMENTPRICE': 142390,
#    'ZD1_CHG': 5680,
#    'ZD2_CHG': 3590,
#    'VOLUME': 23,
#    'TASVOLUME': '',
#    'OPENINTEREST': 18,
#    'OPENINTERESTCHG': 7,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'ni_f    ',
#    'PRODUCTGROUPID': 'ni      ',
#    'PRODUCTSORTNO': 45,
#    'PRODUCTNAME': '镍                  ',
#    'DELIVERYMONTH': '小计',
#    'PRESETTLEMENTPRICE': '',
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': '',
#    'SETTLEMENTPRICE': '',
#    'ZD1_CHG': '',
#    'ZD2_CHG': '',
#    'VOLUME': 716765,
#    'TASVOLUME': '',
#    'OPENINTEREST': 303756,
#    'OPENINTERESTCHG': 48679,
#    'ORDERNO': 0,
#    'ORDERNO2': 50},
#   {'PRODUCTID': 'sn_f    ',
#    'PRODUCTGROUPID': 'sn      ',
#    'PRODUCTSORTNO': 48,
#    'PRODUCTNAME': '锡                  ',
#    'DELIVERYMONTH': '2103',
#    'PRESETTLEMENTPRICE': 170060,
#    'OPENPRICE': 174800,
#    'HIGHESTPRICE': 180260,
#    'LOWESTPRICE': 174350,
#    'CLOSEPRICE': 180260,
#    'SETTLEMENTPRICE': 177760,
#    'ZD1_CHG': 10200,
#    'ZD2_CHG': 7700,
#    'VOLUME': 7735,
#    'TASVOLUME': '',
#    'OPENINTEREST': 5125,
#    'OPENINTERESTCHG': -344,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sn_f    ',
#    'PRODUCTGROUPID': 'sn      ',
#    'PRODUCTSORTNO': 48,
#    'PRODUCTNAME': '锡                  ',
#    'DELIVERYMONTH': '2104',
#    'PRESETTLEMENTPRICE': 171380,
#    'OPENPRICE': 174920,
#    'HIGHESTPRICE': 181660,
#    'LOWESTPRICE': 174880,
#    'CLOSEPRICE': 181660,
#    'SETTLEMENTPRICE': 178610,
#    'ZD1_CHG': 10280,
#    'ZD2_CHG': 7230,
#    'VOLUME': 108211,
#    'TASVOLUME': '',
#    'OPENINTEREST': 43446,
#    'OPENINTERESTCHG': 8876,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sn_f    ',
#    'PRODUCTGROUPID': 'sn      ',
#    'PRODUCTSORTNO': 48,
#    'PRODUCTNAME': '锡                  ',
#    'DELIVERYMONTH': '2105',
#    'PRESETTLEMENTPRICE': 171290,
#    'OPENPRICE': 176700,
#    'HIGHESTPRICE': 181560,
#    'LOWESTPRICE': 175000,
#    'CLOSEPRICE': 181560,
#    'SETTLEMENTPRICE': 178570,
#    'ZD1_CHG': 10270,
#    'ZD2_CHG': 7280,
#    'VOLUME': 22704,
#    'TASVOLUME': '',
#    'OPENINTEREST': 26236,
#    'OPENINTERESTCHG': 2358,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sn_f    ',
#    'PRODUCTGROUPID': 'sn      ',
#    'PRODUCTSORTNO': 48,
#    'PRODUCTNAME': '锡                  ',
#    'DELIVERYMONTH': '2106',
#    'PRESETTLEMENTPRICE': 171960,
#    'OPENPRICE': 175270,
#    'HIGHESTPRICE': 182270,
#    'LOWESTPRICE': 175270,
#    'CLOSEPRICE': 182270,
#    'SETTLEMENTPRICE': 178800,
#    'ZD1_CHG': 10310,
#    'ZD2_CHG': 6840,
#    'VOLUME': 3251,
#    'TASVOLUME': '',
#    'OPENINTEREST': 1499,
#    'OPENINTERESTCHG': 485,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sn_f    ',
#    'PRODUCTGROUPID': 'sn      ',
#    'PRODUCTSORTNO': 48,
#    'PRODUCTNAME': '锡                  ',
#    'DELIVERYMONTH': '2107',
#    'PRESETTLEMENTPRICE': 171530,
#    'OPENPRICE': 175860,
#    'HIGHESTPRICE': 181820,
#    'LOWESTPRICE': 175860,
#    'CLOSEPRICE': 181820,
#    'SETTLEMENTPRICE': 179660,
#    'ZD1_CHG': 10290,
#    'ZD2_CHG': 8130,
#    'VOLUME': 25,
#    'TASVOLUME': '',
#    'OPENINTEREST': 53,
#    'OPENINTERESTCHG': 10,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sn_f    ',
#    'PRODUCTGROUPID': 'sn      ',
#    'PRODUCTSORTNO': 48,
#    'PRODUCTNAME': '锡                  ',
#    'DELIVERYMONTH': '2108',
#    'PRESETTLEMENTPRICE': 172060,
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': 180220,
#    'SETTLEMENTPRICE': 180220,
#    'ZD1_CHG': 8160,
#    'ZD2_CHG': 8160,
#    'VOLUME': 0,
#    'TASVOLUME': '',
#    'OPENINTEREST': 2,
#    'OPENINTERESTCHG': 0,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sn_f    ',
#    'PRODUCTGROUPID': 'sn      ',
#    'PRODUCTSORTNO': 48,
#    'PRODUCTNAME': '锡                  ',
#    'DELIVERYMONTH': '2109',
#    'PRESETTLEMENTPRICE': 172410,
#    'OPENPRICE': 177800,
#    'HIGHESTPRICE': 182190,
#    'LOWESTPRICE': 177800,
#    'CLOSEPRICE': 182190,
#    'SETTLEMENTPRICE': 178990,
#    'ZD1_CHG': 9780,
#    'ZD2_CHG': 6580,
#    'VOLUME': 17,
#    'TASVOLUME': '',
#    'OPENINTEREST': 18,
#    'OPENINTERESTCHG': 2,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sn_f    ',
#    'PRODUCTGROUPID': 'sn      ',
#    'PRODUCTSORTNO': 48,
#    'PRODUCTNAME': '锡                  ',
#    'DELIVERYMONTH': '2110',
#    'PRESETTLEMENTPRICE': 172340,
#    'OPENPRICE': 178000,
#    'HIGHESTPRICE': 181970,
#    'LOWESTPRICE': 177100,
#    'CLOSEPRICE': 181970,
#    'SETTLEMENTPRICE': 178860,
#    'ZD1_CHG': 9630,
#    'ZD2_CHG': 6520,
#    'VOLUME': 5,
#    'TASVOLUME': '',
#    'OPENINTEREST': 22,
#    'OPENINTERESTCHG': 2,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sn_f    ',
#    'PRODUCTGROUPID': 'sn      ',
#    'PRODUCTSORTNO': 48,
#    'PRODUCTNAME': '锡                  ',
#    'DELIVERYMONTH': '2111',
#    'PRESETTLEMENTPRICE': 170220,
#    'OPENPRICE': 178650,
#    'HIGHESTPRICE': 178650,
#    'LOWESTPRICE': 178650,
#    'CLOSEPRICE': 178650,
#    'SETTLEMENTPRICE': 178650,
#    'ZD1_CHG': 8430,
#    'ZD2_CHG': 8430,
#    'VOLUME': 1,
#    'TASVOLUME': '',
#    'OPENINTEREST': 5,
#    'OPENINTERESTCHG': 0,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sn_f    ',
#    'PRODUCTGROUPID': 'sn      ',
#    'PRODUCTSORTNO': 48,
#    'PRODUCTNAME': '锡                  ',
#    'DELIVERYMONTH': '2112',
#    'PRESETTLEMENTPRICE': 168930,
#    'OPENPRICE': 179000,
#    'HIGHESTPRICE': 179000,
#    'LOWESTPRICE': 179000,
#    'CLOSEPRICE': 179000,
#    'SETTLEMENTPRICE': 179000,
#    'ZD1_CHG': 10070,
#    'ZD2_CHG': 10070,
#    'VOLUME': 1,
#    'TASVOLUME': '',
#    'OPENINTEREST': 4,
#    'OPENINTERESTCHG': 0,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sn_f    ',
#    'PRODUCTGROUPID': 'sn      ',
#    'PRODUCTSORTNO': 48,
#    'PRODUCTNAME': '锡                  ',
#    'DELIVERYMONTH': '2201',
#    'PRESETTLEMENTPRICE': 171790,
#    'OPENPRICE': 175100,
#    'HIGHESTPRICE': 182080,
#    'LOWESTPRICE': 175100,
#    'CLOSEPRICE': 181920,
#    'SETTLEMENTPRICE': 178810,
#    'ZD1_CHG': 10130,
#    'ZD2_CHG': 7020,
#    'VOLUME': 18,
#    'TASVOLUME': '',
#    'OPENINTEREST': 22,
#    'OPENINTERESTCHG': 7,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sn_f    ',
#    'PRODUCTGROUPID': 'sn      ',
#    'PRODUCTSORTNO': 48,
#    'PRODUCTNAME': '锡                  ',
#    'DELIVERYMONTH': '2202',
#    'PRESETTLEMENTPRICE': 170700,
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': 171010,
#    'SETTLEMENTPRICE': 171010,
#    'ZD1_CHG': 310,
#    'ZD2_CHG': 310,
#    'VOLUME': 0,
#    'TASVOLUME': '',
#    'OPENINTEREST': 0,
#    'OPENINTERESTCHG': 0,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sn_f    ',
#    'PRODUCTGROUPID': 'sn      ',
#    'PRODUCTSORTNO': 48,
#    'PRODUCTNAME': '锡                  ',
#    'DELIVERYMONTH': '小计',
#    'PRESETTLEMENTPRICE': '',
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': '',
#    'SETTLEMENTPRICE': '',
#    'ZD1_CHG': '',
#    'ZD2_CHG': '',
#    'VOLUME': 141968,
#    'TASVOLUME': '',
#    'OPENINTEREST': 76432,
#    'OPENINTERESTCHG': 11396,
#    'ORDERNO': 0,
#    'ORDERNO2': 50},
#   {'PRODUCTID': 'au_f    ',
#    'PRODUCTGROUPID': 'au      ',
#    'PRODUCTSORTNO': 50,
#    'PRODUCTNAME': '黄金                ',
#    'DELIVERYMONTH': '2103',
#    'PRESETTLEMENTPRICE': 372.64,
#    'OPENPRICE': 373.98,
#    'HIGHESTPRICE': 374.3,
#    'LOWESTPRICE': 369.96,
#    'CLOSEPRICE': 370.44,
#    'SETTLEMENTPRICE': 370.96,
#    'ZD1_CHG': -2.2,
#    'ZD2_CHG': -1.68,
#    'VOLUME': 47,
#    'TASVOLUME': '',
#    'OPENINTEREST': 53,
#    'OPENINTERESTCHG': -7,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'au_f    ',
#    'PRODUCTGROUPID': 'au      ',
#    'PRODUCTSORTNO': 50,
#    'PRODUCTNAME': '黄金                ',
#    'DELIVERYMONTH': '2104',
#    'PRESETTLEMENTPRICE': 372.56,
#    'OPENPRICE': 374,
#    'HIGHESTPRICE': 375.24,
#    'LOWESTPRICE': 369.52,
#    'CLOSEPRICE': 371.32,
#    'SETTLEMENTPRICE': 372.5,
#    'ZD1_CHG': -1.24,
#    'ZD2_CHG': -0.06,
#    'VOLUME': 27159,
#    'TASVOLUME': '',
#    'OPENINTEREST': 28764,
#    'OPENINTERESTCHG': -3445,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'au_f    ',
#    'PRODUCTGROUPID': 'au      ',
#    'PRODUCTSORTNO': 50,
#    'PRODUCTNAME': '黄金                ',
#    'DELIVERYMONTH': '2105',
#    'PRESETTLEMENTPRICE': 373.3,
#    'OPENPRICE': 375.58,
#    'HIGHESTPRICE': 376.46,
#    'LOWESTPRICE': 370,
#    'CLOSEPRICE': 372.38,
#    'SETTLEMENTPRICE': 375.28,
#    'ZD1_CHG': -0.92,
#    'ZD2_CHG': 1.98,
#    'VOLUME': 137,
#    'TASVOLUME': '',
#    'OPENINTEREST': 27,
#    'OPENINTERESTCHG': -45,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'au_f    ',
#    'PRODUCTGROUPID': 'au      ',
#    'PRODUCTSORTNO': 50,
#    'PRODUCTNAME': '黄金                ',
#    'DELIVERYMONTH': '2106',
#    'PRESETTLEMENTPRICE': 373.64,
#    'OPENPRICE': 374.5,
#    'HIGHESTPRICE': 376.46,
#    'LOWESTPRICE': 370.64,
#    'CLOSEPRICE': 372.46,
#    'SETTLEMENTPRICE': 373.5,
#    'ZD1_CHG': -1.18,
#    'ZD2_CHG': -0.14,
#    'VOLUME': 162778,
#    'TASVOLUME': '',
#    'OPENINTEREST': 124132,
#    'OPENINTERESTCHG': 8838,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'au_f    ',
#    'PRODUCTGROUPID': 'au      ',
#    'PRODUCTSORTNO': 50,
#    'PRODUCTNAME': '黄金                ',
#    'DELIVERYMONTH': '2108',
#    'PRESETTLEMENTPRICE': 375.04,
#    'OPENPRICE': 376.2,
#    'HIGHESTPRICE': 377.84,
#    'LOWESTPRICE': 372.1,
#    'CLOSEPRICE': 373.84,
#    'SETTLEMENTPRICE': 374.84,
#    'ZD1_CHG': -1.2,
#    'ZD2_CHG': -0.2,
#    'VOLUME': 26046,
#    'TASVOLUME': '',
#    'OPENINTEREST': 21202,
#    'OPENINTERESTCHG': 258,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'au_f    ',
#    'PRODUCTGROUPID': 'au      ',
#    'PRODUCTSORTNO': 50,
#    'PRODUCTNAME': '黄金                ',
#    'DELIVERYMONTH': '2110',
#    'PRESETTLEMENTPRICE': 376.58,
#    'OPENPRICE': 377.62,
#    'HIGHESTPRICE': 379.28,
#    'LOWESTPRICE': 373.64,
#    'CLOSEPRICE': 375.52,
#    'SETTLEMENTPRICE': 376.4,
#    'ZD1_CHG': -1.06,
#    'ZD2_CHG': -0.18,
#    'VOLUME': 9734,
#    'TASVOLUME': '',
#    'OPENINTEREST': 13779,
#    'OPENINTERESTCHG': -480,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'au_f    ',
#    'PRODUCTGROUPID': 'au      ',
#    'PRODUCTSORTNO': 50,
#    'PRODUCTNAME': '黄金                ',
#    'DELIVERYMONTH': '2112',
#    'PRESETTLEMENTPRICE': 377.76,
#    'OPENPRICE': 378.8,
#    'HIGHESTPRICE': 380.5,
#    'LOWESTPRICE': 375,
#    'CLOSEPRICE': 376.68,
#    'SETTLEMENTPRICE': 377.28,
#    'ZD1_CHG': -1.08,
#    'ZD2_CHG': -0.48,
#    'VOLUME': 405,
#    'TASVOLUME': '',
#    'OPENINTEREST': 1260,
#    'OPENINTERESTCHG': 78,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'au_f    ',
#    'PRODUCTGROUPID': 'au      ',
#    'PRODUCTSORTNO': 50,
#    'PRODUCTNAME': '黄金                ',
#    'DELIVERYMONTH': '2202',
#    'PRESETTLEMENTPRICE': 379.1,
#    'OPENPRICE': 379.88,
#    'HIGHESTPRICE': 380.76,
#    'LOWESTPRICE': 375.28,
#    'CLOSEPRICE': 378.02,
#    'SETTLEMENTPRICE': 378.4,
#    'ZD1_CHG': -1.08,
#    'ZD2_CHG': -0.7,
#    'VOLUME': 12,
#    'TASVOLUME': '',
#    'OPENINTEREST': 23,
#    'OPENINTERESTCHG': 2,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'au_f    ',
#    'PRODUCTGROUPID': 'au      ',
#    'PRODUCTSORTNO': 50,
#    'PRODUCTNAME': '黄金                ',
#    'DELIVERYMONTH': '小计',
#    'PRESETTLEMENTPRICE': '',
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': '',
#    'SETTLEMENTPRICE': '',
#    'ZD1_CHG': '',
#    'ZD2_CHG': '',
#    'VOLUME': 226318,
#    'TASVOLUME': '',
#    'OPENINTEREST': 189240,
#    'OPENINTERESTCHG': 5199,
#    'ORDERNO': 0,
#    'ORDERNO2': 50},
#   {'PRODUCTID': 'ag_f    ',
#    'PRODUCTGROUPID': 'ag      ',
#    'PRODUCTSORTNO': 60,
#    'PRODUCTNAME': '白银                ',
#    'DELIVERYMONTH': '2103',
#    'PRESETTLEMENTPRICE': 5550,
#    'OPENPRICE': 5532,
#    'HIGHESTPRICE': 5587,
#    'LOWESTPRICE': 5420,
#    'CLOSEPRICE': 5479,
#    'SETTLEMENTPRICE': 5506,
#    'ZD1_CHG': -71,
#    'ZD2_CHG': -44,
#    'VOLUME': 19228,
# ...
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'nr_f    ',
#    'PRODUCTGROUPID': 'nr      ',
#    'PRODUCTSORTNO': 105,
#    'PRODUCTNAME': '20号胶              ',
#    'DELIVERYMONTH': '2201',
#    'PRESETTLEMENTPRICE': 11260,
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': 11230,
#    'SETTLEMENTPRICE': 11230,
#    'ZD1_CHG': -30,
#    'ZD2_CHG': -30,
#    'VOLUME': 0,
#    'TASVOLUME': '',
#    'OPENINTEREST': 0,
#    'OPENINTERESTCHG': 0,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'nr_f    ',
#    'PRODUCTGROUPID': 'nr      ',
#    'PRODUCTSORTNO': 105,
#    'PRODUCTNAME': '20号胶              ',
#    'DELIVERYMONTH': '2202',
#    'PRESETTLEMENTPRICE': 11705,
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': 11705,
#    'SETTLEMENTPRICE': 11705,
#    'ZD1_CHG': 0,
#    'ZD2_CHG': 0,
#    'VOLUME': 0,
#    'TASVOLUME': '',
#    'OPENINTEREST': 0,
#    'OPENINTERESTCHG': 0,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'nr_f    ',
#    'PRODUCTGROUPID': 'nr      ',
#    'PRODUCTSORTNO': 105,
#    'PRODUCTNAME': '20号胶              ',
#    'DELIVERYMONTH': '小计',
#    'PRESETTLEMENTPRICE': '',
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': '',
#    'SETTLEMENTPRICE': '',
#    'ZD1_CHG': '',
#    'ZD2_CHG': '',
#    'VOLUME': 59593,
#    'TASVOLUME': '',
#    'OPENINTEREST': 56119,
#    'OPENINTERESTCHG': 3739,
#    'ORDERNO': 0,
#    'ORDERNO2': 50},
#   {'PRODUCTID': 'sp_f    ',
#    'PRODUCTGROUPID': 'sp      ',
#    'PRODUCTSORTNO': 110,
#    'PRODUCTNAME': '纸浆                ',
#    'DELIVERYMONTH': '2103',
#    'PRESETTLEMENTPRICE': 6878,
#    'OPENPRICE': 6872,
#    'HIGHESTPRICE': 6978,
#    'LOWESTPRICE': 6870,
#    'CLOSEPRICE': 6964,
#    'SETTLEMENTPRICE': 6928,
#    'ZD1_CHG': 86,
#    'ZD2_CHG': 50,
#    'VOLUME': 49710,
#    'TASVOLUME': '',
#    'OPENINTEREST': 42671,
#    'OPENINTERESTCHG': -7513,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sp_f    ',
#    'PRODUCTGROUPID': 'sp      ',
#    'PRODUCTSORTNO': 110,
#    'PRODUCTNAME': '纸浆                ',
#    'DELIVERYMONTH': '2104',
#    'PRESETTLEMENTPRICE': 6888,
#    'OPENPRICE': 6900,
#    'HIGHESTPRICE': 7010,
#    'LOWESTPRICE': 6888,
#    'CLOSEPRICE': 6990,
#    'SETTLEMENTPRICE': 6954,
#    'ZD1_CHG': 102,
#    'ZD2_CHG': 66,
#    'VOLUME': 39776,
#    'TASVOLUME': '',
#    'OPENINTEREST': 123219,
#    'OPENINTERESTCHG': 4060,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sp_f    ',
#    'PRODUCTGROUPID': 'sp      ',
#    'PRODUCTSORTNO': 110,
#    'PRODUCTNAME': '纸浆                ',
#    'DELIVERYMONTH': '2105',
#    'PRESETTLEMENTPRICE': 6822,
#    'OPENPRICE': 6820,
#    'HIGHESTPRICE': 7002,
#    'LOWESTPRICE': 6802,
#    'CLOSEPRICE': 6972,
#    'SETTLEMENTPRICE': 6928,
#    'ZD1_CHG': 150,
#    'ZD2_CHG': 106,
#    'VOLUME': 440742,
#    'TASVOLUME': '',
#    'OPENINTEREST': 212270,
#    'OPENINTERESTCHG': 29448,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sp_f    ',
#    'PRODUCTGROUPID': 'sp      ',
#    'PRODUCTSORTNO': 110,
#    'PRODUCTNAME': '纸浆                ',
#    'DELIVERYMONTH': '2106',
#    'PRESETTLEMENTPRICE': 6780,
#    'OPENPRICE': 6768,
#    'HIGHESTPRICE': 6960,
#    'LOWESTPRICE': 6768,
#    'CLOSEPRICE': 6940,
#    'SETTLEMENTPRICE': 6886,
#    'ZD1_CHG': 160,
#    'ZD2_CHG': 106,
#    'VOLUME': 12527,
#    'TASVOLUME': '',
#    'OPENINTEREST': 32087,
#    'OPENINTERESTCHG': 1138,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sp_f    ',
#    'PRODUCTGROUPID': 'sp      ',
#    'PRODUCTSORTNO': 110,
#    'PRODUCTNAME': '纸浆                ',
#    'DELIVERYMONTH': '2107',
#    'PRESETTLEMENTPRICE': 6694,
#    'OPENPRICE': 6702,
#    'HIGHESTPRICE': 6884,
#    'LOWESTPRICE': 6672,
#    'CLOSEPRICE': 6866,
#    'SETTLEMENTPRICE': 6804,
#    'ZD1_CHG': 172,
#    'ZD2_CHG': 110,
#    'VOLUME': 2339,
#    'TASVOLUME': '',
#    'OPENINTEREST': 1336,
#    'OPENINTERESTCHG': -87,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sp_f    ',
#    'PRODUCTGROUPID': 'sp      ',
#    'PRODUCTSORTNO': 110,
#    'PRODUCTNAME': '纸浆                ',
#    'DELIVERYMONTH': '2108',
#    'PRESETTLEMENTPRICE': 6592,
#    'OPENPRICE': 6594,
#    'HIGHESTPRICE': 6814,
#    'LOWESTPRICE': 6572,
#    'CLOSEPRICE': 6814,
#    'SETTLEMENTPRICE': 6698,
#    'ZD1_CHG': 222,
#    'ZD2_CHG': 106,
#    'VOLUME': 1432,
#    'TASVOLUME': '',
#    'OPENINTEREST': 725,
#    'OPENINTERESTCHG': -50,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sp_f    ',
#    'PRODUCTGROUPID': 'sp      ',
#    'PRODUCTSORTNO': 110,
#    'PRODUCTNAME': '纸浆                ',
#    'DELIVERYMONTH': '2109',
#    'PRESETTLEMENTPRICE': 6496,
#    'OPENPRICE': 6500,
#    'HIGHESTPRICE': 6742,
#    'LOWESTPRICE': 6470,
#    'CLOSEPRICE': 6728,
#    'SETTLEMENTPRICE': 6630,
#    'ZD1_CHG': 232,
#    'ZD2_CHG': 134,
#    'VOLUME': 7930,
#    'TASVOLUME': '',
#    'OPENINTEREST': 8706,
#    'OPENINTERESTCHG': 1492,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sp_f    ',
#    'PRODUCTGROUPID': 'sp      ',
#    'PRODUCTSORTNO': 110,
#    'PRODUCTNAME': '纸浆                ',
#    'DELIVERYMONTH': '2110',
#    'PRESETTLEMENTPRICE': 6406,
#    'OPENPRICE': 6492,
#    'HIGHESTPRICE': 6664,
#    'LOWESTPRICE': 6492,
#    'CLOSEPRICE': 6664,
#    'SETTLEMENTPRICE': 6572,
#    'ZD1_CHG': 258,
#    'ZD2_CHG': 166,
#    'VOLUME': 10,
#    'TASVOLUME': '',
#    'OPENINTEREST': 43,
#    'OPENINTERESTCHG': 7,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sp_f    ',
#    'PRODUCTGROUPID': 'sp      ',
#    'PRODUCTSORTNO': 110,
#    'PRODUCTNAME': '纸浆                ',
#    'DELIVERYMONTH': '2111',
#    'PRESETTLEMENTPRICE': 6426,
#    'OPENPRICE': 6474,
#    'HIGHESTPRICE': 6614,
#    'LOWESTPRICE': 6474,
#    'CLOSEPRICE': 6614,
#    'SETTLEMENTPRICE': 6564,
#    'ZD1_CHG': 188,
#    'ZD2_CHG': 138,
#    'VOLUME': 7,
#    'TASVOLUME': '',
#    'OPENINTEREST': 32,
#    'OPENINTERESTCHG': 4,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sp_f    ',
#    'PRODUCTGROUPID': 'sp      ',
#    'PRODUCTSORTNO': 110,
#    'PRODUCTNAME': '纸浆                ',
#    'DELIVERYMONTH': '2112',
#    'PRESETTLEMENTPRICE': 6428,
#    'OPENPRICE': 6484,
#    'HIGHESTPRICE': 6600,
#    'LOWESTPRICE': 6426,
#    'CLOSEPRICE': 6600,
#    'SETTLEMENTPRICE': 6516,
#    'ZD1_CHG': 172,
#    'ZD2_CHG': 88,
#    'VOLUME': 106,
#    'TASVOLUME': '',
#    'OPENINTEREST': 204,
#    'OPENINTERESTCHG': 51,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sp_f    ',
#    'PRODUCTGROUPID': 'sp      ',
#    'PRODUCTSORTNO': 110,
#    'PRODUCTNAME': '纸浆                ',
#    'DELIVERYMONTH': '2201',
#    'PRESETTLEMENTPRICE': 6440,
#    'OPENPRICE': 6352,
#    'HIGHESTPRICE': 6586,
#    'LOWESTPRICE': 6340,
#    'CLOSEPRICE': 6586,
#    'SETTLEMENTPRICE': 6504,
#    'ZD1_CHG': 146,
#    'ZD2_CHG': 64,
#    'VOLUME': 67,
#    'TASVOLUME': '',
#    'OPENINTEREST': 89,
#    'OPENINTERESTCHG': 17,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sp_f    ',
#    'PRODUCTGROUPID': 'sp      ',
#    'PRODUCTSORTNO': 110,
#    'PRODUCTNAME': '纸浆                ',
#    'DELIVERYMONTH': '2202',
#    'PRESETTLEMENTPRICE': 6390,
#    'OPENPRICE': 6402,
#    'HIGHESTPRICE': 6402,
#    'LOWESTPRICE': 6402,
#    'CLOSEPRICE': 6402,
#    'SETTLEMENTPRICE': 6402,
#    'ZD1_CHG': 12,
#    'ZD2_CHG': 12,
#    'VOLUME': 2,
#    'TASVOLUME': '',
#    'OPENINTEREST': 9,
#    'OPENINTERESTCHG': 0,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sp_f    ',
#    'PRODUCTGROUPID': 'sp      ',
#    'PRODUCTSORTNO': 110,
#    'PRODUCTNAME': '纸浆                ',
#    'DELIVERYMONTH': '小计',
#    'PRESETTLEMENTPRICE': '',
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': '',
#    'SETTLEMENTPRICE': '',
#    'ZD1_CHG': '',
#    'ZD2_CHG': '',
#    'VOLUME': 554648,
#    'TASVOLUME': '',
#    'OPENINTEREST': 421391,
#    'OPENINTERESTCHG': 28567,
#    'ORDERNO': 0,
#    'ORDERNO2': 50},
#   {'PRODUCTID': '总计',
#    'PRODUCTGROUPID': '',
#    'PRODUCTSORTNO': 9999,
#    'PRODUCTNAME': '总计',
#    'DELIVERYMONTH': '',
#    'PRESETTLEMENTPRICE': '',
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': '',
#    'SETTLEMENTPRICE': '',
#    'ZD1_CHG': '',
#    'ZD2_CHG': '',
#    'VOLUME': 9099800,
#    'TASVOLUME': 0,
#    'OPENINTEREST': 6762240,
#    'OPENINTERESTCHG': 288493,
#    'ORDERNO': 0,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sc_tas  ',
#    'PRODUCTGROUPID': 'sc_tas  ',
#    'PRODUCTSORTNO': 90,
#    'PRODUCTNAME': '原油TAS             ',
#    'DELIVERYMONTH': '2104',
#    'PRESETTLEMENTPRICE': '',
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': '',
#    'SETTLEMENTPRICE': '',
#    'ZD1_CHG': '',
#    'ZD2_CHG': '',
#    'VOLUME': '',
#    'TASVOLUME': 0,
#    'OPENINTEREST': '',
#    'OPENINTERESTCHG': '',
#    'ORDERNO': 999,
#    'ORDERNO2': 0},
#   {'PRODUCTID': 'sc_tas  ',
#    'PRODUCTGROUPID': 'sc_tas  ',
#    'PRODUCTSORTNO': 90,
#    'PRODUCTNAME': '原油TAS             ',
#    'DELIVERYMONTH': '小计',
#    'PRESETTLEMENTPRICE': '',
#    'OPENPRICE': '',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'CLOSEPRICE': '',
#    'SETTLEMENTPRICE': '',
#    'ZD1_CHG': '',
#    'ZD2_CHG': '',
#    'VOLUME': '',
#    'TASVOLUME': 0,
#    'OPENINTEREST': '',
#    'OPENINTERESTCHG': '',
#    'ORDERNO': 999,
#    'ORDERNO2': 0}],
#  'o_curproduct': [{'PRODUCTID': 'cu_f    ',
#    'PRODUCTGROUPID': 'cu      ',
#    'PRODUCTSORTNO': 10,
#    'PRODUCTNAME': '铜                  ',
#    'HIGHESTPRICE': 64510,
#    'LOWESTPRICE': 62890,
#    'AVGPRICE': 63532.911,
#    'VOLUME': 404187,
#    'TURNOVER': 1283.9588265,
#    'YEARVOLUME': 765.7248,
#    'YEARTURNOVER': 22620.2111585},
#   {'PRODUCTID': 'bc_f    ',
#    'PRODUCTGROUPID': 'bc      ',
#    'PRODUCTSORTNO': 15,
#    'PRODUCTNAME': '铜(BC)              ',
#    'HIGHESTPRICE': 57700,
#    'LOWESTPRICE': 56060,
#    'AVGPRICE': 56531.237,
#    'VOLUME': 38358,
#    'TURNOVER': 108.4212585,
#    'YEARVOLUME': 58.0883,
#    'YEARTURNOVER': 1529.516483},
#   {'PRODUCTID': 'al_f    ',
#    'PRODUCTGROUPID': 'al      ',
#    'PRODUCTSORTNO': 20,
#    'PRODUCTNAME': '铝                  ',
#    'HIGHESTPRICE': 16680,
#    'LOWESTPRICE': 15985,
#    'AVGPRICE': 16510.447,
#    'VOLUME': 377780,
#    'TURNOVER': 311.8660155,
#    'YEARVOLUME': 936.3892,
#    'YEARTURNOVER': 7126.10437925},
#   {'PRODUCTID': 'zn_f    ',
#    'PRODUCTGROUPID': 'zn      ',
#    'PRODUCTSORTNO': 30,
#    'PRODUCTNAME': '锌                  ',
#    'HIGHESTPRICE': 21670,
#    'LOWESTPRICE': 20895,
#    'AVGPRICE': 21484.268,
#    'VOLUME': 220239,
#    'TURNOVER': 236.58385025,
#    'YEARVOLUME': 663.3127,
#    'YEARTURNOVER': 6766.11056625},
#   {'PRODUCTID': 'pb_f    ',
#    'PRODUCTGROUPID': 'pb      ',
#    'PRODUCTSORTNO': 40,
#    'PRODUCTNAME': '铅                  ',
#    'HIGHESTPRICE': 15780,
#    'LOWESTPRICE': 15245,
#    'AVGPRICE': 15500.079,
#    'VOLUME': 121270,
#    'TURNOVER': 93.98472925,
#    'YEARVOLUME': 254.759,
#    'YEARTURNOVER': 1924.208259},
#   {'PRODUCTID': 'ni_f    ',
#    'PRODUCTGROUPID': 'ni      ',
#    'PRODUCTSORTNO': 45,
#    'PRODUCTNAME': '镍                  ',
#    'HIGHESTPRICE': 144990,
#    'LOWESTPRICE': 139000,
#    'AVGPRICE': 142012.771,
#    'VOLUME': 716765,
#    'TURNOVER': 1017.8978382,
#    'YEARVOLUME': 2682.2184,
#    'YEARTURNOVER': 35514.4440715},
#   {'PRODUCTID': 'sn_f    ',
#    'PRODUCTGROUPID': 'sn      ',
#    'PRODUCTSORTNO': 48,
#    'PRODUCTNAME': '锡                  ',
#    'HIGHESTPRICE': 182270,
#    'LOWESTPRICE': 174350,
#    'AVGPRICE': 178566.785,
#    'VOLUME': 141968,
#    'TURNOVER': 253.5076937,
#    'YEARVOLUME': 357.5288,
#    'YEARTURNOVER': 5898.2039553},
#   {'PRODUCTID': 'au_f    ',
#    'PRODUCTGROUPID': 'au      ',
#    'PRODUCTSORTNO': 50,
#    'PRODUCTNAME': '黄金                ',
#    'HIGHESTPRICE': 380.76,
#    'LOWESTPRICE': 369.52,
#    'AVGPRICE': 373.685,
#    'VOLUME': 226318,
#    'TURNOVER': 845.716319,
#    'YEARVOLUME': 596.87,
#    'YEARTURNOVER': 23206.367666},
#   {'PRODUCTID': 'ag_f    ',
#    'PRODUCTGROUPID': 'ag      ',
#    'PRODUCTSORTNO': 60,
#    'PRODUCTNAME': '白银                ',
#    'HIGHESTPRICE': 5768,
#    'LOWESTPRICE': 5420,
#    'AVGPRICE': 5569.653,
#    'VOLUME': 1182010,
#    'TURNOVER': 987.50783805,
#    'YEARVOLUME': 4882.0521,
#    'YEARTURNOVER': 40107.9319998},
#   {'PRODUCTID': 'rb_f    ',
#    'PRODUCTGROUPID': 'rb      ',
#    'PRODUCTSORTNO': 70,
#    'PRODUCTNAME': '螺纹钢              ',
#    'HIGHESTPRICE': 4672,
#    'LOWESTPRICE': 4235,
#    'AVGPRICE': 4524.587,
#    'VOLUME': 1713781,
#    'TURNOVER': 775.4150527,
#    'YEARVOLUME': 5735.257,
#    'YEARTURNOVER': 24825.873527},
#   {'PRODUCTID': 'wr_f    ',
#    'PRODUCTGROUPID': 'wr      ',
#    'PRODUCTSORTNO': 80,
#    'PRODUCTNAME': '线材                ',
#    'HIGHESTPRICE': 5236,
#    'LOWESTPRICE': 5069,
#    'AVGPRICE': 5120,
#    'VOLUME': 33,
#    'TURNOVER': 0.016896,
#    'YEARVOLUME': 0.1037,
#    'YEARTURNOVER': 0.4858949},
#   {'PRODUCTID': 'hc_f    ',
#    'PRODUCTGROUPID': 'hc      ',
#    'PRODUCTSORTNO': 85,
#    'PRODUCTNAME': '热轧卷板            ',
#    'HIGHESTPRICE': 4794,
#    'LOWESTPRICE': 4368,
#    'AVGPRICE': 4679.639,
#    'VOLUME': 524031,
#    'TURNOVER': 245.2275903,
#    'YEARVOLUME': 2014.7625,
#    'YEARTURNOVER': 9000.195101},
#   {'PRODUCTID': 'ss_f    ',
#    'PRODUCTGROUPID': 'ss      ',
#    'PRODUCTSORTNO': 87,
#    'PRODUCTNAME': '不锈钢              ',
#    'HIGHESTPRICE': 15360,
#    'LOWESTPRICE': 14800,
#    'AVGPRICE': 15105.537,
#    'VOLUME': 174978,
#    'TURNOVER': 132.15682925,
#    'YEARVOLUME': 478.2257,
#    'YEARTURNOVER': 3417.00255675},
#   {'PRODUCTID': 'sc_f    ',
#    'PRODUCTGROUPID': 'sc      ',
#    'PRODUCTSORTNO': 90,
#    'PRODUCTNAME': '原油                ',
#    'HIGHESTPRICE': 410.8,
#    'LOWESTPRICE': 379,
#    'AVGPRICE': 391.782,
#    'VOLUME': 144443,
#    'TURNOVER': 565.901376,
#    'YEARVOLUME': 511.2092,
#    'YEARTURNOVER': 17469.915203},
#   {'PRODUCTID': 'lu_f    ',
#    'PRODUCTGROUPID': 'lu      ',
#    'PRODUCTSORTNO': 91,
#    'PRODUCTNAME': '低硫燃料油          ',
#    'HIGHESTPRICE': 3347,
#    'LOWESTPRICE': 3108,
#    'AVGPRICE': 3192.923,
#    'VOLUME': 85471,
#    'TURNOVER': 27.2902303,
#    'YEARVOLUME': 242.6646,
#    'YEARTURNOVER': 696.1571358},
#   {'PRODUCTID': 'fu_f    ',
#    'PRODUCTGROUPID': 'fu      ',
#    'PRODUCTSORTNO': 92,
#    'PRODUCTNAME': '燃料油              ',
#    'HIGHESTPRICE': 2420,
#    'LOWESTPRICE': 2305,
#    'AVGPRICE': 2356.698,
#    'VOLUME': 1179135,
#    'TURNOVER': 277.8864542,
#    'YEARVOLUME': 4214.6206,
#    'YEARTURNOVER': 9229.8364066},
#   {'PRODUCTID': 'bu_f    ',
#    'PRODUCTGROUPID': 'bu      ',
#    'PRODUCTSORTNO': 95,
#    'PRODUCTNAME': '石油沥青            ',
#    'HIGHESTPRICE': 3176,
#    'LOWESTPRICE': 2950,
#    'AVGPRICE': 3006.829,
#    'VOLUME': 565981,
#    'TURNOVER': 170.1808326,
#    'YEARVOLUME': 1808.0886,
#    'YEARTURNOVER': 4930.0884846},
#   {'PRODUCTID': 'ru_f    ',
#    'PRODUCTGROUPID': 'ru      ',
#    'PRODUCTSORTNO': 100,
#    'PRODUCTNAME': '天然橡胶            ',
#    'HIGHESTPRICE': 16600,
#    'LOWESTPRICE': 15135,
#    'AVGPRICE': 15434.216,
#    'VOLUME': 668811,
#    'TURNOVER': 1032.257299,
#    'YEARVOLUME': 1642.9982,
#    'YEARTURNOVER': 23940.147209},
#   {'PRODUCTID': 'nr_f    ',
#    'PRODUCTGROUPID': 'nr      ',
#    'PRODUCTSORTNO': 105,
#    'PRODUCTNAME': '20号胶              ',
#    'HIGHESTPRICE': 11860,
#    'LOWESTPRICE': 11020,
#    'AVGPRICE': 11435.682,
#    'VOLUME': 59593,
#    'TURNOVER': 68.1486585,
#    'YEARVOLUME': 91.2344,
#    'YEARTURNOVER': 989.498244},
#   {'PRODUCTID': 'sp_f    ',
#    'PRODUCTGROUPID': 'sp      ',
#    'PRODUCTSORTNO': 110,
#    'PRODUCTNAME': '纸浆                ',
#    'HIGHESTPRICE': 7010,
#    'LOWESTPRICE': 6340,
#    'AVGPRICE': 6924.408,
#    'VOLUME': 554648,
#    'TURNOVER': 384.0609028,
#    'YEARVOLUME': 1892.8151,
#    'YEARTURNOVER': 12103.4026036},
#   {'PRODUCTID': '总计',
#    'PRODUCTGROUPID': '',
#    'PRODUCTSORTNO': 9999,
#    'PRODUCTNAME': '总计',
#    'HIGHESTPRICE': '',
#    'LOWESTPRICE': '',
#    'AVGPRICE': '',
#    'VOLUME': 9099800,
#    'TURNOVER': 8817.9864906,
#    'YEARVOLUME': 29828.9229,
#    'YEARTURNOVER': 251295.70090485}],
#  'o_curmetalindex': [{'TRADINGDAY': '20210219',
#    'LASTPRICE': 3641.75,
#    'OPENPRICE': 3590.6,
#    'CLOSEPRICE': 3641.75,
#    'PRECLOSEPRICE': 3576.09,
#    'UPDOWN': 65.66,
#    'UPDOWN1': 95.38,
#    'UPDOWN2': 60.72,
#    'HIGHESTPRICE': 3649.08,
#    'LOWESTPRICE': 3584.5,
#    'AVGPRICE': 3604.04,
#    'SETTLEMENTPRICE': 3607.09}],
#  'o_year': '2021',
#  'o_month': '02',
#  'o_day': '19',
#  'o_weekday': '五',
#  'o_year_num': '30',
#  'o_total_num': '6882',
#  'o_trade_day': '6890',
#  'o_IMChangeDate': '20150813',
#  'showlength': '1',
#  'o_code': 0,
#  'o_msg': '交易快讯查询成功',
#  'report_date': '20210219',
#  'update_date': '20210219 20:00:44',
#  'print_date': '20210219 20:00:45'}

# %%
# 使用 json 库读取 JSON 内容
datas_heyue = []
results_heyue = json_data['o_curinstrument']
for heyue in results_heyue:
    data_heyue = {
                '日期': '20220219',
                '交易所': 'SQH',
                '商品名称': heyue['PRODUCTNAME'].strip(),
                '正常成交量': heyue['VOLUME'],
                'TAS成交量': heyue['TASVOLUME'],
                '持仓量': heyue['OPENINTEREST'],
                '收盘价': heyue['CLOSEPRICE'],
                '备注':heyue['DELIVERYMONTH'].strip()
                }
    datas_heyue.append(data_heyue)
df_heyue = pd.DataFrame(datas_heyue)
df_heyue
# Out:
#            日期  交易所   商品名称    正常成交量 TAS成交量      持仓量    收盘价    备注
# 0    20220219  SQH      铜   106671           68887  64170  2103
# 1    20220219  SQH      铜   199534          147830  64320  2104
# 2    20220219  SQH      铜    69650           75898  64370  2105
# 3    20220219  SQH      铜    22045           32707  64390  2106
# 4    20220219  SQH      铜     5058           11851  64330  2107
# ..        ...  ...    ...      ...    ...      ...    ...   ...
# 260  20220219  SQH     纸浆        2               9   6402  2202
# 261  20220219  SQH     纸浆   554648          421391           小计
# 262  20220219  SQH     总计  9099800      0  6762240
# 263  20220219  SQH  原油TAS               0                  2104
# 264  20220219  SQH  原油TAS               0                    小计
#
# [265 rows x 8 columns]

# %%
# 方法二：使用 pandas 库的 json_normalize() 方法读取多层嵌套 JSON 格式文本
df_json = pd.json_normalize(json_data, ['o_curinstrument'],max_level=1)
df_json
# Out:
#     PRODUCTID PRODUCTGROUPID  PRODUCTSORTNO          PRODUCTNAME  \
# 0    cu_f           cu                   10  铜
# 1    cu_f           cu                   10  铜
# 2    cu_f           cu                   10  铜
# 3    cu_f           cu                   10  铜
# 4    cu_f           cu                   10  铜
# ..        ...            ...            ...                  ...
# 260  sp_f           sp                  110   纸浆
# 261  sp_f           sp                  110   纸浆
# 262        总计                          9999                   总计
# 263  sc_tas         sc_tas               90   原油TAS
# 264  sc_tas         sc_tas               90   原油TAS
#
#     DELIVERYMONTH PRESETTLEMENTPRICE OPENPRICE HIGHESTPRICE LOWESTPRICE  \
# 0            2103              62600     63440        64330       62890
# 1            2104              62730     63390        64470       63000
# 2            2105              62710     63480        64510       63030
# 3            2106              62640     63400        64470       63000
# 4            2107              62700     63350        64420       62950
# ..            ...                ...       ...          ...         ...
# 260          2202               6390      6402         6402        6402
# 261            小计
# 262
# 263          2104
# 264            小计
#
#     CLOSEPRICE SETTLEMENTPRICE ZD1_CHG ZD2_CHG   VOLUME TASVOLUME  \
# 0        64170           63390    1570     790   106671
# 1        64320           63560    1590     830   199534
# 2        64370           63600    1660     890    69650
# 3        64390           63620    1750     980    22045
# 4        64330           63680    1630     980     5058
# ..         ...             ...     ...     ...      ...       ...
# 260       6402            6402      12      12        2
# 261                                              554648
# 262                                             9099800         0
# 263                                                             0
# 264                                                             0
#
#     OPENINTEREST OPENINTERESTCHG  ORDERNO  ORDERNO2
# 0          68887          -11804        0         0
# 1         147830           19979        0         0
# 2          75898            5289        0         0
# 3          32707            3916        0         0
# 4          11851            1791        0         0
# ..           ...             ...      ...       ...
# 260            9               0        0         0
# 261       421391           28567        0        50
# 262      6762240          288493        0         0
# 263                                   999         0
# 264                                   999         0
#
# [265 rows x 19 columns]

# %%
# 方法三：使用 jsonpath 库读取 JSON 格式文本
product_name = jsonpath(json_data, '$..PRODUCTNAME')
volume = jsonpath(json_data, '$..VOLUME')
TAS_volume = jsonpath(json_data, '$..TASVOLUME')
open_interest = jsonpath(json_data, '$..OPENINTEREST')
close_price = jsonpath(json_data, '$..CLOSEPRICE')
delivery_month = jsonpath(json_data, '$..DELIVERYMONTH')
list_content = [product_name,volume,TAS_volume,open_interest,close_price,delivery_month]
df_jsonpath = pd.DataFrame(list_content)
df_jsonpath = df_jsonpath.T
df_jsonpath.rename(columns={0:'product_name',1:'volume',2:'TAS_volume',3:'open_interest',4:'close_price',5:'delivery_month'},inplace=True)
df_jsonpath = df_jsonpath.applymap(str) # 将所有元素转换为文本
df_jsonpath = df_jsonpath.applymap(lambda x:x.replace('None','')) # 替换内容
df_jsonpath
# Out:
#             product_name   volume TAS_volume open_interest close_price  \
# 0    铜                     106671                    68887       64170
# 1    铜                     199534                   147830       64320
# 2    铜                      69650                    75898       64370
# 3    铜                      22045                    32707       64390
# 4    铜                       5058                    11851       64330
# ..                   ...      ...        ...           ...         ...
# 281     石油沥青               565981
# 282     天然橡胶               668811
# 283   20号胶                  59593
# 284   纸浆                   554648
# 285                   总计  9099800
#
#     delivery_month
# 0             2103
# 1             2104
# 2             2105
# 3             2106
# 4             2107
# ..             ...
# 281
# 282
# 283
# 284
# 285
#
# [286 rows x 6 columns]
